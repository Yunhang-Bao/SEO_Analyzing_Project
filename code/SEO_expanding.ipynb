# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#datafor seo
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import requests
from urllib.parse import urlparse
import base64
import time
import json

# === 认证信息 ===
USERNAME = "support@sociosquares.com"
PASSWORD = "135b6aab5381a28b"
AUTH_TOKEN = base64.b64encode(f"{USERNAME}:{PASSWORD}".encode()).decode()
HEADERS = {
    "Authorization": f"Basic {AUTH_TOKEN}",
    "Content-Type": "application/json"
}

# === San Francisco 文件路径 ===
SF_TOP3_PATH = "/content/drive/MyDrive/Part 2/San Francisco/top_3_results_filtered.csv"
SF_TOP10_PATH = "/content/drive/MyDrive/Part 2/San Francisco/top_10_results_filtered.csv"
OUTPUT_PATH = "/content/drive/MyDrive/Part 2/San Francisco/"

def extract_domain(url):
    try:
        return urlparse(url).netloc.replace("www.", "")
    except:
        return None

def get_domain_summary(domain):
    """获取域名的summary数据 - 包含各种权威指标"""
    try:
        print(f"    📊 Getting summary for: {domain}")

        response = requests.post(
            "https://api.dataforseo.com/v3/backlinks/summary/live",
            headers=HEADERS,
            json=[{"target": domain, "mode": "as_is"}]
        )

        if response.status_code == 200:
            data = response.json()
            if (data and
                data.get("status_code") == 20000 and
                data.get("tasks") and
                len(data["tasks"]) > 0):

                task_result = data["tasks"][0]
                if task_result.get("status_code") == 20000:
                    result_data = task_result.get("result", [])
                    if result_data and len(result_data) > 0:
                        summary = result_data[0]

                        # 提取各种指标
                        domain_rank = summary.get("rank", 0)
                        backlinks_count = summary.get("backlinks", 0)
                        referring_domains = summary.get("referring_domains", 0)
                        referring_main_domains = summary.get("referring_main_domains", 0)

                        print(f"    ✅ Summary: Rank={domain_rank}, Backlinks={backlinks_count:,}")

                        return {
                            "domain_rank": domain_rank,
                            "backlinks_count": backlinks_count,
                            "referring_domains": referring_domains,
                            "referring_main_domains": referring_main_domains
                        }

        print(f"    ⚠️ No summary data for {domain}")
        return None

    except Exception as e:
        print(f"    ❌ Summary error for {domain}: {e}")
        return None

def get_domain_backlinks_sample(domain):
    """获取域名的sample backlinks"""
    try:
        print(f"    🔗 Getting backlinks sample for: {domain}")

        response = requests.post(
            "https://api.dataforseo.com/v3/backlinks/backlinks/live",
            headers=HEADERS,
            json=[{"target": domain, "limit": 5, "mode": "as_is"}]
        )

        if response.status_code == 200:
            data = response.json()
            if (data and
                data.get("status_code") == 20000 and
                data.get("tasks") and
                len(data["tasks"]) > 0):

                task_result = data["tasks"][0]
                if task_result.get("status_code") == 20000:
                    result_data = task_result.get("result", [])
                    if result_data and len(result_data) > 0:
                        domain_result = result_data[0]
                        items = domain_result.get("items", [])

                        # 提取top backlinks和详细信息
                        top_backlinks = []
                        for item in items:
                            url_from = item.get("url_from")
                            if url_from:
                                top_backlinks.append(url_from)

                        print(f"    ✅ Found {len(top_backlinks)} sample backlinks")
                        return top_backlinks

        print(f"    ⚠️ No backlinks sample for {domain}")
        return []

    except Exception as e:
        print(f"    ❌ Backlinks error for {domain}: {e}")
        return []

def get_page_rank_for_domain(domain):
    """获取域名主页的page rank"""
    try:
        main_page_url = f"https://{domain}/"
        print(f"    📄 Getting page rank for: {main_page_url}")

        response = requests.post(
            "https://api.dataforseo.com/v3/backlinks/summary/live",
            headers=HEADERS,
            json=[{"target": main_page_url, "mode": "as_is"}]
        )

        if response.status_code == 200:
            data = response.json()
            if (data and
                data.get("status_code") == 20000 and
                data.get("tasks") and
                len(data["tasks"]) > 0):

                task_result = data["tasks"][0]
                if task_result.get("status_code") == 20000:
                    result_data = task_result.get("result", [])
                    if result_data and len(result_data) > 0:
                        page_summary = result_data[0]
                        page_rank = page_summary.get("rank", 0)

                        print(f"    ✅ Page rank: {page_rank}")
                        return page_rank

        print(f"    ⚠️ No page rank for {domain}")
        return 0

    except Exception as e:
        print(f"    ❌ Page rank error for {domain}: {e}")
        return 0

def enrich_single_domain(domain):
    """完整enrichment单个域名 - 获取所有指标"""
    print(f"\n  🎯 ENRICHING: {domain}")
    print(f"  " + "="*50)

    enrichment_data = {
        "domain_authority": 0,
        "page_authority": 0,
        "backlinks_count": 0,
        "top_backlinks": [],
        "trust_flow": 0,
        "referring_domains": 0,
        "referring_main_domains": 0
    }

    # 1. 获取域名summary数据
    summary_data = get_domain_summary(domain)
    if summary_data:
        enrichment_data["domain_authority"] = summary_data["domain_rank"]
        enrichment_data["backlinks_count"] = summary_data["backlinks_count"]
        enrichment_data["referring_domains"] = summary_data["referring_domains"]
        enrichment_data["referring_main_domains"] = summary_data["referring_main_domains"]

    time.sleep(1)  # API延迟

    # 2. 获取页面rank
    page_rank = get_page_rank_for_domain(domain)
    enrichment_data["page_authority"] = page_rank

    time.sleep(1)  # API延迟

    # 3. 获取sample backlinks
    top_backlinks = get_domain_backlinks_sample(domain)
    enrichment_data["top_backlinks"] = top_backlinks

    # 4. Trust flow (DataForSEO没有直接提供，使用domain rank作为近似)
    enrichment_data["trust_flow"] = enrichment_data["domain_authority"]

    # 显示结果摘要
    print(f"  📊 RESULTS:")
    print(f"    Domain Authority: {enrichment_data['domain_authority']}")
    print(f"    Page Authority: {enrichment_data['page_authority']}")
    print(f"    Backlinks Count: {enrichment_data['backlinks_count']:,}")
    print(f"    Top Backlinks: {len(enrichment_data['top_backlinks'])}")
    print(f"    Referring Domains: {enrichment_data['referring_domains']}")

    return enrichment_data

def process_sf_file_complete(file_path, file_type):
    """完整处理San Francisco文件 - 所有域名，所有指标"""
    print(f"\n🌉 PROCESSING: San Francisco {file_type.upper()} - COMPLETE VERSION")
    print("=" * 80)

    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        return None

    try:
        # 读取文件
        df = pd.read_csv(file_path)
        print(f"📄 Loaded {len(df)} rows from {file_type}")

        # 检查必要列
        required_columns = ["keyword", "city", "ranking", "link"]
        missing_columns = [col for col in required_columns if col not in df.columns]
        if missing_columns:
            print(f"❌ Missing columns: {missing_columns}")
            return None

        # 提取域名
        df["domain"] = df["link"].apply(extract_domain)

        # 获取所有唯一域名
        all_domains = df["domain"].dropna().unique()
        domain_counts = df["domain"].value_counts()

        print(f"🌐 Found {len(all_domains)} unique domains")
        print(f"📊 Total rows to process: {len(df)}")
        print(f"🎯 Will enrich ALL {len(all_domains)} domains")
        print(f"💰 Estimated cost: ${len(all_domains) * 0.06:.2f} (3 API calls per domain)")
        print(f"⏱️ Estimated time: {len(all_domains) * 4 / 60:.1f} minutes")

        # 显示top domains
        print(f"\n🔝 Top 10 domains by frequency:")
        for i, (domain, count) in enumerate(domain_counts.head(10).items()):
            print(f"  {i+1}. {domain} ({count} occurrences)")

        # 确认是否继续
        print(f"\n⚠️ This will make {len(all_domains) * 3} API calls!")
        print(f"🚀 Starting enrichment process in 3 seconds...")
        time.sleep(3)

        # Enrichment process
        print(f"\n📊 STARTING ENRICHMENT PROCESS...")
        print("=" * 80)

        enrichment_results = {}
        total_cost = 0

        for i, domain in enumerate(all_domains):
            if not domain or pd.isna(domain):
                continue

            print(f"\n📍 DOMAIN {i+1}/{len(all_domains)}: {domain}")
            print(f"🔄 Progress: {((i+1)/len(all_domains)*100):.1f}%")

            # 获取完整enrichment数据
            domain_data = enrich_single_domain(domain)
            enrichment_results[domain] = domain_data

            # 估算成本
            total_cost += 0.06  # 每个域名约3次API调用

            # 进度延迟
            if i < len(all_domains) - 1:
                print(f"  💤 Waiting 3 seconds...")
                time.sleep(3)

        # 应用enrichment结果到dataframe
        print(f"\n📋 APPLYING RESULTS TO DATAFRAME...")
        df["domain_authority"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("domain_authority", 0))
        df["page_authority"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("page_authority", 0))
        df["backlinks_count"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("backlinks_count", 0))
        df["top_backlinks"] = df["domain"].map(lambda d: "; ".join(enrichment_results.get(d, {}).get("top_backlinks", [])))
        df["trust_flow"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("trust_flow", 0))
        df["referring_domains"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("referring_domains", 0))
        df["referring_main_domains"] = df["domain"].map(lambda d: enrichment_results.get(d, {}).get("referring_main_domains", 0))

        # 保存结果
        output_filename = f"San_Francisco_{file_type}_COMPLETE_enriched.csv"
        output_path = os.path.join(OUTPUT_PATH, output_filename)
        df.to_csv(output_path, index=False)

        # 统计报告
        total_backlinks = df["backlinks_count"].sum()
        rows_with_backlinks = (df["backlinks_count"] > 0).sum()
        max_backlinks = df["backlinks_count"].max()
        max_domain_authority = df["domain_authority"].max()
        max_page_authority = df["page_authority"].max()

        print(f"\n🎉 {file_type.upper()} COMPLETE ENRICHMENT FINISHED!")
        print("=" * 80)
        print(f"💾 Saved to: {output_filename}")
        print(f"📊 STATISTICS:")
        print(f"  📈 Total backlinks: {total_backlinks:,}")
        print(f"  🎯 Rows with backlinks: {rows_with_backlinks:,}/{len(df):,}")
        print(f"  🏆 Max backlinks: {max_backlinks:,}")
        print(f"  🏅 Max domain authority: {max_domain_authority}")
        print(f"  🏅 Max page authority: {max_page_authority}")
        print(f"  💰 Actual cost: ${total_cost:.2f}")

        return df, enrichment_results

    except Exception as e:
        print(f"❌ Error processing {file_type}: {e}")
        import traceback
        traceback.print_exc()
        return None

def main():
    """主函数 - 完整处理San Francisco所有数据"""
    print("🌉 SAN FRANCISCO COMPLETE DOMAIN ENRICHMENT SYSTEM")
    print("=" * 100)
    print("🎯 Target: San Francisco TOP3 and TOP10 files - ALL DOMAINS, ALL METRICS")
    print("📊 Metrics: Domain Authority, Page Authority, Backlinks, Trust Flow, Referring Domains")
    print("⚠️ WARNING: This will process ALL unique domains (expensive!)")

    # 预估成本
    # 读取文件以获取域名数量
    try:
        df3 = pd.read_csv(SF_TOP3_PATH)
        df10 = pd.read_csv(SF_TOP10_PATH)
        df3["domain"] = df3["link"].apply(extract_domain)
        df10["domain"] = df10["link"].apply(extract_domain)

        domains3 = set(df3["domain"].dropna().unique())
        domains10 = set(df10["domain"].dropna().unique())
        all_unique_domains = domains3.union(domains10)

        estimated_cost = len(all_unique_domains) * 0.06
        estimated_time = len(all_unique_domains) * 4 / 60

        print(f"\n📊 PRE-ANALYSIS:")
        print(f"  TOP3 unique domains: {len(domains3)}")
        print(f"  TOP10 unique domains: {len(domains10)}")
        print(f"  Combined unique domains: {len(all_unique_domains)}")
        print(f"  💰 Estimated total cost: ${estimated_cost:.2f}")
        print(f"  ⏱️ Estimated total time: {estimated_time:.1f} minutes")

    except Exception as e:
        print(f"⚠️ Could not pre-analyze files: {e}")

    results_summary = {}
    total_api_calls = 0

    # 处理TOP3文件
    print(f"\n🚀 STARTING TOP3 COMPLETE ENRICHMENT...")
    top3_result = process_sf_file_complete(SF_TOP3_PATH, "top3")

    if top3_result:
        df3, enrich3 = top3_result
        results_summary["top3"] = {
            "status": "Success",
            "rows": len(df3),
            "domains_processed": len(enrich3)
        }
        total_api_calls += len(enrich3) * 3
    else:
        results_summary["top3"] = {"status": "Failed"}

    # 延迟后处理TOP10文件
    print(f"\n💤 WAITING 10 seconds before TOP10...")
    time.sleep(10)

    print(f"\n🚀 STARTING TOP10 COMPLETE ENRICHMENT...")
    top10_result = process_sf_file_complete(SF_TOP10_PATH, "top10")

    if top10_result:
        df10, enrich10 = top10_result
        results_summary["top10"] = {
            "status": "Success",
            "rows": len(df10),
            "domains_processed": len(enrich10)
        }
        total_api_calls += len(enrich10) * 3
    else:
        results_summary["top10"] = {"status": "Failed"}

    # 最终报告
    print(f"\n🎉 SAN FRANCISCO COMPLETE ENRICHMENT FINISHED!")
    print("=" * 100)

    for file_type, result in results_summary.items():
        if result["status"] == "Success":
            print(f"✅ {file_type.upper()}: {result['rows']:,} rows, {result['domains_processed']} domains enriched")
        else:
            print(f"❌ {file_type.upper()}: Failed")

    print(f"\n📊 FINAL STATISTICS:")
    print(f"🔧 Total API calls made: {total_api_calls}")
    print(f"💰 Actual total cost: ~${total_api_calls * 0.02:.2f}")
    print(f"📂 Output location: {OUTPUT_PATH}")
    print(f"📄 Generated files:")
    print(f"  - San_Francisco_top3_COMPLETE_enriched.csv")
    print(f"  - San_Francisco_top10_COMPLETE_enriched.csv")

    # 域名分析汇总
    if top3_result and top10_result:
        print(f"\n🏆 TOP PERFORMING DOMAINS ANALYSIS:")

        # 合并所有enrichment结果
        all_domains = {}
        all_domains.update(enrich3)
        all_domains.update(enrich10)

        # 按不同指标排序
        by_backlinks = sorted(all_domains.items(), key=lambda x: x[1]["backlinks_count"], reverse=True)
        by_domain_auth = sorted(all_domains.items(), key=lambda x: x[1]["domain_authority"], reverse=True)

        print(f"\n🔗 Top 5 by Backlinks:")
        for i, (domain, data) in enumerate(by_backlinks[:5]):
            print(f"  {i+1}. {domain}: {data['backlinks_count']:,} backlinks")

        print(f"\n🏅 Top 5 by Domain Authority:")
        for i, (domain, data) in enumerate(by_domain_auth[:5]):
            print(f"  {i+1}. {domain}: {data['domain_authority']} authority")

    print(f"\n✨ COMPLETE ENRICHMENT SUCCESSFUL!")
    print(f"🎯 ALL METRICS POPULATED: Domain Authority, Page Authority, Trust Flow, Backlinks!")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#   🎯 ENRICHING: goldinglawyers.com
#   ==================================================
#     📊 Getting summary for: goldinglawyers.com
#     ✅ Summary: Rank=333, Backlinks=14,254
#     📄 Getting page rank for: https://goldinglawyers.com/
#     ✅ Page rank: 48
#     🔗 Getting backlinks sample for: goldinglawyers.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 333
#     Page Authority: 48
#     Backlinks Count: 14,254
#     Top Backlinks: 5
#     Referring Domains: 1052
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 397/656: morganlewis.com
# 🔄 Progress: 60.5%
#
#   🎯 ENRICHING: morganlewis.com
#   ==================================================
#     📊 Getting summary for: morganlewis.com
#     ✅ Summary: Rank=417, Backlinks=316,237
#     📄 Getting page rank for: https://morganlewis.com/
#     ✅ Page rank: 252
#     🔗 Getting backlinks sample for: morganlewis.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 417
#     Page Authority: 252
#     Backlinks Count: 316,237
#     Top Backlinks: 5
#     Referring Domains: 9440
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 398/656: taxhelpers.com
# 🔄 Progress: 60.7%
#
#   🎯 ENRICHING: taxhelpers.com
#   ==================================================
#     📊 Getting summary for: taxhelpers.com
#     ✅ Summary: Rank=251, Backlinks=3,145
#     📄 Getting page rank for: https://taxhelpers.com/
#     ✅ Page rank: 121
#     🔗 Getting backlinks sample for: taxhelpers.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 251
#     Page Authority: 121
#     Backlinks Count: 3,145
#     Top Backlinks: 5
#     Referring Domains: 225
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 399/656: ftb.ca.gov
# 🔄 Progress: 60.8%
#
#   🎯 ENRICHING: ftb.ca.gov
#   ==================================================
#     📊 Getting summary for: ftb.ca.gov
#     ✅ Summary: Rank=261, Backlinks=4,170
#     📄 Getting page rank for: https://ftb.ca.gov/
#     ✅ Page rank: 201
#     🔗 Getting backlinks sample for: ftb.ca.gov
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 261
#     Page Authority: 201
#     Backlinks Count: 4,170
#     Top Backlinks: 5
#     Referring Domains: 583
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 400/656: taxes.ca.gov
# 🔄 Progress: 61.0%
#
#   🎯 ENRICHING: taxes.ca.gov
#   ==================================================
#     📊 Getting summary for: taxes.ca.gov
#     ✅ Summary: Rank=182, Backlinks=424
#     📄 Getting page rank for: https://taxes.ca.gov/
#     ✅ Page rank: 60
#     🔗 Getting backlinks sample for: taxes.ca.gov
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 182
#     Page Authority: 60
#     Backlinks Count: 424
#     Top Backlinks: 5
#     Referring Domains: 286
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 401/656: irs.gov
# 🔄 Progress: 61.1%
#
#   🎯 ENRICHING: irs.gov
#   ==================================================
#     📊 Getting summary for: irs.gov
#     ✅ Summary: Rank=670, Backlinks=46,344,147
#     📄 Getting page rank for: https://irs.gov/
#     ✅ Page rank: 345
#     🔗 Getting backlinks sample for: irs.gov
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 670
#     Page Authority: 345
#     Backlinks Count: 46,344,147
#     Top Backlinks: 5
#     Referring Domains: 315521
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 402/656: collective.com
# 🔄 Progress: 61.3%
#
#   🎯 ENRICHING: collective.com
#   ==================================================
#     📊 Getting summary for: collective.com
#     ✅ Summary: Rank=305, Backlinks=9,474
#     📄 Getting page rank for: https://collective.com/
#     ✅ Page rank: 172
#     🔗 Getting backlinks sample for: collective.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 305
#     Page Authority: 172
#     Backlinks Count: 9,474
#     Top Backlinks: 5
#     Referring Domains: 1979
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 403/656: sftreasurer.org
# 🔄 Progress: 61.4%
#
#   🎯 ENRICHING: sftreasurer.org
#   ==================================================
#     📊 Getting summary for: sftreasurer.org
#     ✅ Summary: Rank=318, Backlinks=18,442
#     📄 Getting page rank for: https://sftreasurer.org/
#     ✅ Page rank: 225
#     🔗 Getting backlinks sample for: sftreasurer.org
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 318
#     Page Authority: 225
#     Backlinks Count: 18,442
#     Top Backlinks: 5
#     Referring Domains: 2303
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 404/656: incorporatecalifornia.com
# 🔄 Progress: 61.6%
#
#   🎯 ENRICHING: incorporatecalifornia.com
#   ==================================================
#     📊 Getting summary for: incorporatecalifornia.com
#     ✅ Summary: Rank=212, Backlinks=3,217
#     📄 Getting page rank for: https://incorporatecalifornia.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: incorporatecalifornia.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 212
#     Page Authority: 0
#     Backlinks Count: 3,217
#     Top Backlinks: 5
#     Referring Domains: 143
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 405/656: hrblock.com
# 🔄 Progress: 61.7%
#
#   🎯 ENRICHING: hrblock.com
#   ==================================================
#     📊 Getting summary for: hrblock.com
#     ✅ Summary: Rank=458, Backlinks=733,612
#     📄 Getting page rank for: https://hrblock.com/
#     ✅ Page rank: 343
#     🔗 Getting backlinks sample for: hrblock.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 458
#     Page Authority: 343
#     Backlinks Count: 733,612
#     Top Backlinks: 5
#     Referring Domains: 33497
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 406/656: wkblaw.com
# 🔄 Progress: 61.9%
#
#   🎯 ENRICHING: wkblaw.com
#   ==================================================
#     📊 Getting summary for: wkblaw.com
#     ✅ Summary: Rank=201, Backlinks=2,166
#     📄 Getting page rank for: https://wkblaw.com/
#     ✅ Page rank: 69
#     🔗 Getting backlinks sample for: wkblaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 201
#     Page Authority: 69
#     Backlinks Count: 2,166
#     Top Backlinks: 5
#     Referring Domains: 252
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 407/656: albmac.com
# 🔄 Progress: 62.0%
#
#   🎯 ENRICHING: albmac.com
#   ==================================================
#     📊 Getting summary for: albmac.com
#     ✅ Summary: Rank=180, Backlinks=839
#     📄 Getting page rank for: https://albmac.com/
#     ✅ Page rank: 130
#     🔗 Getting backlinks sample for: albmac.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 180
#     Page Authority: 130
#     Backlinks Count: 839
#     Top Backlinks: 5
#     Referring Domains: 139
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 408/656: katzoffriggs.com
# 🔄 Progress: 62.2%
#
#   🎯 ENRICHING: katzoffriggs.com
#   ==================================================
#     📊 Getting summary for: katzoffriggs.com
#     ✅ Summary: Rank=95, Backlinks=280
#     📄 Getting page rank for: https://katzoffriggs.com/
#     ✅ Page rank: 40
#     🔗 Getting backlinks sample for: katzoffriggs.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 95
#     Page Authority: 40
#     Backlinks Count: 280
#     Top Backlinks: 5
#     Referring Domains: 161
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 409/656: mcdlawyers.net
# 🔄 Progress: 62.3%
#
#   🎯 ENRICHING: mcdlawyers.net
#   ==================================================
#     📊 Getting summary for: mcdlawyers.net
#     ✅ Summary: Rank=138, Backlinks=223
#     📄 Getting page rank for: https://mcdlawyers.net/
#     ✅ Page rank: 54
#     🔗 Getting backlinks sample for: mcdlawyers.net
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 138
#     Page Authority: 54
#     Backlinks Count: 223
#     Top Backlinks: 5
#     Referring Domains: 126
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 410/656: profiles.superlawyers.com
# 🔄 Progress: 62.5%
#
#   🎯 ENRICHING: profiles.superlawyers.com
#   ==================================================
#     📊 Getting summary for: profiles.superlawyers.com
#     ✅ Summary: Rank=510, Backlinks=846,990
#     📄 Getting page rank for: https://profiles.superlawyers.com/
#     ✅ Page rank: 140
#     🔗 Getting backlinks sample for: profiles.superlawyers.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 510
#     Page Authority: 140
#     Backlinks Count: 846,990
#     Top Backlinks: 5
#     Referring Domains: 16746
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 411/656: kjmlaw.com
# 🔄 Progress: 62.7%
#
#   🎯 ENRICHING: kjmlaw.com
#   ==================================================
#     📊 Getting summary for: kjmlaw.com
#     ✅ Summary: Rank=179, Backlinks=503
#     📄 Getting page rank for: https://kjmlaw.com/
#     ✅ Page rank: 44
#     🔗 Getting backlinks sample for: kjmlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 179
#     Page Authority: 44
#     Backlinks Count: 503
#     Top Backlinks: 5
#     Referring Domains: 148
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 412/656: gtlaw.com
# 🔄 Progress: 62.8%
#
#   🎯 ENRICHING: gtlaw.com
#   ==================================================
#     📊 Getting summary for: gtlaw.com
#     ✅ Summary: Rank=407, Backlinks=288,026
#     📄 Getting page rank for: https://gtlaw.com/
#     ✅ Page rank: 218
#     🔗 Getting backlinks sample for: gtlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 407
#     Page Authority: 218
#     Backlinks Count: 288,026
#     Top Backlinks: 5
#     Referring Domains: 7559
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 413/656: twsglaw.com
# 🔄 Progress: 63.0%
#
#   🎯 ENRICHING: twsglaw.com
#   ==================================================
#     📊 Getting summary for: twsglaw.com
#     ✅ Summary: Rank=109, Backlinks=623
#     📄 Getting page rank for: https://twsglaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: twsglaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 109
#     Page Authority: 0
#     Backlinks Count: 623
#     Top Backlinks: 5
#     Referring Domains: 85
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 414/656: sftaxappeal.com
# 🔄 Progress: 63.1%
#
#   🎯 ENRICHING: sftaxappeal.com
#   ==================================================
#     📊 Getting summary for: sftaxappeal.com
#     ✅ Summary: Rank=118, Backlinks=89
#     📄 Getting page rank for: https://sftaxappeal.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: sftaxappeal.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 118
#     Page Authority: 0
#     Backlinks Count: 89
#     Top Backlinks: 5
#     Referring Domains: 75
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 415/656: usfca.edu
# 🔄 Progress: 63.3%
#
#   🎯 ENRICHING: usfca.edu
#   ==================================================
#     📊 Getting summary for: usfca.edu
#     ✅ Summary: Rank=450, Backlinks=603,051
#     📄 Getting page rank for: https://usfca.edu/
#     ✅ Page rank: 237
#     🔗 Getting backlinks sample for: usfca.edu
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 450
#     Page Authority: 237
#     Backlinks Count: 603,051
#     Top Backlinks: 5
#     Referring Domains: 28171
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 416/656: uclawsf.edu
# 🔄 Progress: 63.4%
#
#   🎯 ENRICHING: uclawsf.edu
#   ==================================================
#     📊 Getting summary for: uclawsf.edu
#     ✅ Summary: Rank=424, Backlinks=164,267
#     📄 Getting page rank for: https://uclawsf.edu/
#     ✅ Page rank: 324
#     🔗 Getting backlinks sample for: uclawsf.edu
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 424
#     Page Authority: 324
#     Backlinks Count: 164,267
#     Top Backlinks: 5
#     Referring Domains: 7663
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 417/656: sflaw.com
# 🔄 Progress: 63.6%
#
#   🎯 ENRICHING: sflaw.com
#   ==================================================
#     📊 Getting summary for: sflaw.com
#     ✅ Summary: Rank=221, Backlinks=1,482
#     📄 Getting page rank for: https://sflaw.com/
#     ✅ Page rank: 125
#     🔗 Getting backlinks sample for: sflaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 221
#     Page Authority: 125
#     Backlinks Count: 1,482
#     Top Backlinks: 5
#     Referring Domains: 267
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 418/656: dergnoah.com
# 🔄 Progress: 63.7%
#
#   🎯 ENRICHING: dergnoah.com
#   ==================================================
#     📊 Getting summary for: dergnoah.com
#     ✅ Summary: Rank=114, Backlinks=387
#     📄 Getting page rank for: https://dergnoah.com/
#     ✅ Page rank: 39
#     🔗 Getting backlinks sample for: dergnoah.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 114
#     Page Authority: 39
#     Backlinks Count: 387
#     Top Backlinks: 5
#     Referring Domains: 86
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 419/656: mintz.com
# 🔄 Progress: 63.9%
#
#   🎯 ENRICHING: mintz.com
#   ==================================================
#     📊 Getting summary for: mintz.com
#     ✅ Summary: Rank=373, Backlinks=46,507
#     📄 Getting page rank for: https://mintz.com/
#     ✅ Page rank: 201
#     🔗 Getting backlinks sample for: mintz.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 373
#     Page Authority: 201
#     Backlinks Count: 46,507
#     Top Backlinks: 5
#     Referring Domains: 4118
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 420/656: owe.com
# 🔄 Progress: 64.0%
#
#   🎯 ENRICHING: owe.com
#   ==================================================
#     📊 Getting summary for: owe.com
#     ✅ Summary: Rank=198, Backlinks=1,099
#     📄 Getting page rank for: https://owe.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: owe.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 198
#     Page Authority: 0
#     Backlinks Count: 1,099
#     Top Backlinks: 5
#     Referring Domains: 470
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 421/656: boldip.com
# 🔄 Progress: 64.2%
#
#   🎯 ENRICHING: boldip.com
#   ==================================================
#     📊 Getting summary for: boldip.com
#     ✅ Summary: Rank=278, Backlinks=13,280
#     📄 Getting page rank for: https://boldip.com/
#     ✅ Page rank: 216
#     🔗 Getting backlinks sample for: boldip.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 278
#     Page Authority: 216
#     Backlinks Count: 13,280
#     Top Backlinks: 5
#     Referring Domains: 872
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 422/656: kingkelleher.com
# 🔄 Progress: 64.3%
#
#   🎯 ENRICHING: kingkelleher.com
#   ==================================================
#     📊 Getting summary for: kingkelleher.com
#     ✅ Summary: Rank=27, Backlinks=60
#     📄 Getting page rank for: https://kingkelleher.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: kingkelleher.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 27
#     Page Authority: 0
#     Backlinks Count: 60
#     Top Backlinks: 5
#     Referring Domains: 33
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 423/656: kr.law
# 🔄 Progress: 64.5%
#
#   🎯 ENRICHING: kr.law
#   ==================================================
#     📊 Getting summary for: kr.law
#     ✅ Summary: Rank=191, Backlinks=598
#     📄 Getting page rank for: https://kr.law/
#     ✅ Page rank: 115
#     🔗 Getting backlinks sample for: kr.law
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 191
#     Page Authority: 115
#     Backlinks Count: 598
#     Top Backlinks: 5
#     Referring Domains: 321
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 424/656: dhillonlaw.com
# 🔄 Progress: 64.6%
#
#   🎯 ENRICHING: dhillonlaw.com
#   ==================================================
#     📊 Getting summary for: dhillonlaw.com
#     ✅ Summary: Rank=284, Backlinks=4,856
#     📄 Getting page rank for: https://dhillonlaw.com/
#     ✅ Page rank: 20
#     🔗 Getting backlinks sample for: dhillonlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 284
#     Page Authority: 20
#     Backlinks Count: 4,856
#     Top Backlinks: 5
#     Referring Domains: 1757
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 425/656: cerallp.com
# 🔄 Progress: 64.8%
#
#   🎯 ENRICHING: cerallp.com
#   ==================================================
#     📊 Getting summary for: cerallp.com
#     ✅ Summary: Rank=91, Backlinks=131
#     📄 Getting page rank for: https://cerallp.com/
#     ✅ Page rank: 56
#     🔗 Getting backlinks sample for: cerallp.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 91
#     Page Authority: 56
#     Backlinks Count: 131
#     Top Backlinks: 5
#     Referring Domains: 94
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 426/656: millershah.com
# 🔄 Progress: 64.9%
#
#   🎯 ENRICHING: millershah.com
#   ==================================================
#     📊 Getting summary for: millershah.com
#     ✅ Summary: Rank=251, Backlinks=4,635
#     📄 Getting page rank for: https://millershah.com/
#     ✅ Page rank: 212
#     🔗 Getting backlinks sample for: millershah.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 251
#     Page Authority: 212
#     Backlinks Count: 4,635
#     Top Backlinks: 5
#     Referring Domains: 214
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 427/656: rgpimm.com
# 🔄 Progress: 65.1%
#
#   🎯 ENRICHING: rgpimm.com
#   ==================================================
#     📊 Getting summary for: rgpimm.com
#     ✅ Summary: Rank=111, Backlinks=436
#     📄 Getting page rank for: https://rgpimm.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: rgpimm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 111
#     Page Authority: 0
#     Backlinks Count: 436
#     Top Backlinks: 5
#     Referring Domains: 40
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 428/656: ferguslegalip.com
# 🔄 Progress: 65.2%
#
#   🎯 ENRICHING: ferguslegalip.com
#   ==================================================
#     📊 Getting summary for: ferguslegalip.com
#     ✅ Summary: Rank=139, Backlinks=693
#     📄 Getting page rank for: https://ferguslegalip.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: ferguslegalip.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 139
#     Page Authority: 0
#     Backlinks Count: 693
#     Top Backlinks: 5
#     Referring Domains: 187
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 429/656: knobbe.com
# 🔄 Progress: 65.4%
#
#   🎯 ENRICHING: knobbe.com
#   ==================================================
#     📊 Getting summary for: knobbe.com
#     ✅ Summary: Rank=310, Backlinks=12,031
#     📄 Getting page rank for: https://knobbe.com/
#     ✅ Page rank: 170
#     🔗 Getting backlinks sample for: knobbe.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 310
#     Page Authority: 170
#     Backlinks Count: 12,031
#     Top Backlinks: 5
#     Referring Domains: 1165
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 430/656: sfipla.com
# 🔄 Progress: 65.5%
#
#   🎯 ENRICHING: sfipla.com
#   ==================================================
#     📊 Getting summary for: sfipla.com
#     ✅ Summary: Rank=175, Backlinks=919
#     📄 Getting page rank for: https://sfipla.com/
#     ✅ Page rank: 5
#     🔗 Getting backlinks sample for: sfipla.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 175
#     Page Authority: 5
#     Backlinks Count: 919
#     Top Backlinks: 5
#     Referring Domains: 169
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 431/656: goodwinlaw.com
# 🔄 Progress: 65.7%
#
#   🎯 ENRICHING: goodwinlaw.com
#   ==================================================
#     📊 Getting summary for: goodwinlaw.com
#     ✅ Summary: Rank=418, Backlinks=179,359
#     📄 Getting page rank for: https://goodwinlaw.com/
#     ✅ Page rank: 187
#     🔗 Getting backlinks sample for: goodwinlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 418
#     Page Authority: 187
#     Backlinks Count: 179,359
#     Top Backlinks: 5
#     Referring Domains: 4421
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 432/656: desmaraisllp.com
# 🔄 Progress: 65.9%
#
#   🎯 ENRICHING: desmaraisllp.com
#   ==================================================
#     📊 Getting summary for: desmaraisllp.com
#     ✅ Summary: Rank=210, Backlinks=1,392
#     📄 Getting page rank for: https://desmaraisllp.com/
#     ✅ Page rank: 69
#     🔗 Getting backlinks sample for: desmaraisllp.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 210
#     Page Authority: 69
#     Backlinks Count: 1,392
#     Top Backlinks: 5
#     Referring Domains: 168
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 433/656: fr.com
# 🔄 Progress: 66.0%
#
#   🎯 ENRICHING: fr.com
#   ==================================================
#     📊 Getting summary for: fr.com
#     ✅ Summary: Rank=389, Backlinks=67,088
#     📄 Getting page rank for: https://fr.com/
#     ✅ Page rank: 202
#     🔗 Getting backlinks sample for: fr.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 389
#     Page Authority: 202
#     Backlinks Count: 67,088
#     Top Backlinks: 5
#     Referring Domains: 3752
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 434/656: saverilawfirm.com
# 🔄 Progress: 66.2%
#
#   🎯 ENRICHING: saverilawfirm.com
#   ==================================================
#     📊 Getting summary for: saverilawfirm.com
#     ✅ Summary: Rank=251, Backlinks=2,670
#     📄 Getting page rank for: https://saverilawfirm.com/
#     ✅ Page rank: 77
#     🔗 Getting backlinks sample for: saverilawfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 251
#     Page Authority: 77
#     Backlinks Count: 2,670
#     Top Backlinks: 5
#     Referring Domains: 703
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 435/656: ktslaw.com
# 🔄 Progress: 66.3%
#
#   🎯 ENRICHING: ktslaw.com
#   ==================================================
#     📊 Getting summary for: ktslaw.com
#     ✅ Summary: Rank=384, Backlinks=32,753
#     📄 Getting page rank for: https://ktslaw.com/
#     ✅ Page rank: 260
#     🔗 Getting backlinks sample for: ktslaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 384
#     Page Authority: 260
#     Backlinks Count: 32,753
#     Top Backlinks: 5
#     Referring Domains: 2226
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 436/656: patentlawyer.io
# 🔄 Progress: 66.5%
#
#   🎯 ENRICHING: patentlawyer.io
#   ==================================================
#     📊 Getting summary for: patentlawyer.io
#     ✅ Summary: Rank=189, Backlinks=625
#     📄 Getting page rank for: https://patentlawyer.io/
#     ✅ Page rank: 70
#     🔗 Getting backlinks sample for: patentlawyer.io
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 189
#     Page Authority: 70
#     Backlinks Count: 625
#     Top Backlinks: 5
#     Referring Domains: 251
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 437/656: prangerlaw.com
# 🔄 Progress: 66.6%
#
#   🎯 ENRICHING: prangerlaw.com
#   ==================================================
#     📊 Getting summary for: prangerlaw.com
#     ✅ Summary: Rank=112, Backlinks=103
#     📄 Getting page rank for: https://prangerlaw.com/
#     ✅ Page rank: 101
#     🔗 Getting backlinks sample for: prangerlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 112
#     Page Authority: 101
#     Backlinks Count: 103
#     Top Backlinks: 5
#     Referring Domains: 61
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 438/656: rimonlaw.com
# 🔄 Progress: 66.8%
#
#   🎯 ENRICHING: rimonlaw.com
#   ==================================================
#     📊 Getting summary for: rimonlaw.com
#     ✅ Summary: Rank=325, Backlinks=19,491
#     📄 Getting page rank for: https://rimonlaw.com/
#     ✅ Page rank: 204
#     🔗 Getting backlinks sample for: rimonlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 325
#     Page Authority: 204
#     Backlinks Count: 19,491
#     Top Backlinks: 5
#     Referring Domains: 837
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 439/656: trevorcaudlelaw.com
# 🔄 Progress: 66.9%
#
#   🎯 ENRICHING: trevorcaudlelaw.com
#   ==================================================
#     📊 Getting summary for: trevorcaudlelaw.com
#     ✅ Summary: Rank=84, Backlinks=102
#     📄 Getting page rank for: https://trevorcaudlelaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: trevorcaudlelaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 84
#     Page Authority: 0
#     Backlinks Count: 102
#     Top Backlinks: 5
#     Referring Domains: 48
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 440/656: bell-iplaw.com
# 🔄 Progress: 67.1%
#
#   🎯 ENRICHING: bell-iplaw.com
#   ==================================================
#     📊 Getting summary for: bell-iplaw.com
#     ✅ Summary: Rank=196, Backlinks=259
#     📄 Getting page rank for: https://bell-iplaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: bell-iplaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 196
#     Page Authority: 0
#     Backlinks Count: 259
#     Top Backlinks: 5
#     Referring Domains: 74
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 441/656: peillaw.com
# 🔄 Progress: 67.2%
#
#   🎯 ENRICHING: peillaw.com
#   ==================================================
#     📊 Getting summary for: peillaw.com
#     ✅ Summary: Rank=124, Backlinks=154
#     📄 Getting page rank for: https://peillaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: peillaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 124
#     Page Authority: 0
#     Backlinks Count: 154
#     Top Backlinks: 5
#     Referring Domains: 72
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 442/656: adibiip.com
# 🔄 Progress: 67.4%
#
#   🎯 ENRICHING: adibiip.com
#   ==================================================
#     📊 Getting summary for: adibiip.com
#     ✅ Summary: Rank=186, Backlinks=428
#     📄 Getting page rank for: https://adibiip.com/
#     ✅ Page rank: 182
#     🔗 Getting backlinks sample for: adibiip.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 186
#     Page Authority: 182
#     Backlinks Count: 428
#     Top Backlinks: 5
#     Referring Domains: 95
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 443/656: bayoaklaw.com
# 🔄 Progress: 67.5%
#
#   🎯 ENRICHING: bayoaklaw.com
#   ==================================================
#     📊 Getting summary for: bayoaklaw.com
#     ✅ Summary: Rank=157, Backlinks=2,075
#     📄 Getting page rank for: https://bayoaklaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: bayoaklaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 157
#     Page Authority: 0
#     Backlinks Count: 2,075
#     Top Backlinks: 5
#     Referring Domains: 142
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 444/656: clfip.com
# 🔄 Progress: 67.7%
#
#   🎯 ENRICHING: clfip.com
#   ==================================================
#     📊 Getting summary for: clfip.com
#     ✅ Summary: Rank=148, Backlinks=1,748
#     📄 Getting page rank for: https://clfip.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: clfip.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 148
#     Page Authority: 0
#     Backlinks Count: 1,748
#     Top Backlinks: 5
#     Referring Domains: 177
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 445/656: cognitionip.com
# 🔄 Progress: 67.8%
#
#   🎯 ENRICHING: cognitionip.com
#   ==================================================
#     📊 Getting summary for: cognitionip.com
#     ✅ Summary: Rank=186, Backlinks=421
#     📄 Getting page rank for: https://cognitionip.com/
#     ✅ Page rank: 129
#     🔗 Getting backlinks sample for: cognitionip.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 186
#     Page Authority: 129
#     Backlinks Count: 421
#     Top Backlinks: 5
#     Referring Domains: 208
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 446/656: reidllaw.com
# 🔄 Progress: 68.0%
#
#   🎯 ENRICHING: reidllaw.com
#   ==================================================
#     📊 Getting summary for: reidllaw.com
#     ✅ Summary: Rank=58, Backlinks=103
#     📄 Getting page rank for: https://reidllaw.com/
#     ✅ Page rank: 7
#     🔗 Getting backlinks sample for: reidllaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 58
#     Page Authority: 7
#     Backlinks Count: 103
#     Top Backlinks: 5
#     Referring Domains: 30
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 447/656: cohnlg.com
# 🔄 Progress: 68.1%
#
#   🎯 ENRICHING: cohnlg.com
#   ==================================================
#     📊 Getting summary for: cohnlg.com
#     ✅ Summary: Rank=266, Backlinks=11,193
#     📄 Getting page rank for: https://cohnlg.com/
#     ✅ Page rank: 121
#     🔗 Getting backlinks sample for: cohnlg.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 266
#     Page Authority: 121
#     Backlinks Count: 11,193
#     Top Backlinks: 5
#     Referring Domains: 884
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 448/656: raylawfirmpllc.com
# 🔄 Progress: 68.3%
#
#   🎯 ENRICHING: raylawfirmpllc.com
#   ==================================================
#     📊 Getting summary for: raylawfirmpllc.com
#     ✅ Summary: Rank=125, Backlinks=198
#     📄 Getting page rank for: https://raylawfirmpllc.com/
#     ✅ Page rank: 92
#     🔗 Getting backlinks sample for: raylawfirmpllc.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 125
#     Page Authority: 92
#     Backlinks Count: 198
#     Top Backlinks: 5
#     Referring Domains: 110
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 449/656: danielrosslawfirm.com
# 🔄 Progress: 68.4%
#
#   🎯 ENRICHING: danielrosslawfirm.com
#   ==================================================
#     📊 Getting summary for: danielrosslawfirm.com
#     ✅ Summary: Rank=150, Backlinks=408
#     📄 Getting page rank for: https://danielrosslawfirm.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: danielrosslawfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 150
#     Page Authority: 0
#     Backlinks Count: 408
#     Top Backlinks: 5
#     Referring Domains: 157
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 450/656: cooley.com
# 🔄 Progress: 68.6%
#
#   🎯 ENRICHING: cooley.com
#   ==================================================
#     📊 Getting summary for: cooley.com
#     ✅ Summary: Rank=412, Backlinks=167,406
#     📄 Getting page rank for: https://cooley.com/
#     ✅ Page rank: 217
#     🔗 Getting backlinks sample for: cooley.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 412
#     Page Authority: 217
#     Backlinks Count: 167,406
#     Top Backlinks: 5
#     Referring Domains: 6942
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 451/656: wilmerhale.com
# 🔄 Progress: 68.8%
#
#   🎯 ENRICHING: wilmerhale.com
#   ==================================================
#     📊 Getting summary for: wilmerhale.com
#     ✅ Summary: Rank=363, Backlinks=135,274
#     📄 Getting page rank for: https://wilmerhale.com/
#     ✅ Page rank: 187
#     🔗 Getting backlinks sample for: wilmerhale.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 363
#     Page Authority: 187
#     Backlinks Count: 135,274
#     Top Backlinks: 5
#     Referring Domains: 6402
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 452/656: manatt.com
# 🔄 Progress: 68.9%
#
#   🎯 ENRICHING: manatt.com
#   ==================================================
#     📊 Getting summary for: manatt.com
#     ✅ Summary: Rank=344, Backlinks=127,432
#     📄 Getting page rank for: https://manatt.com/
#     ✅ Page rank: 221
#     🔗 Getting backlinks sample for: manatt.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 344
#     Page Authority: 221
#     Backlinks Count: 127,432
#     Top Backlinks: 5
#     Referring Domains: 4765
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 453/656: kkc.com
# 🔄 Progress: 69.1%
#
#   🎯 ENRICHING: kkc.com
#   ==================================================
#     📊 Getting summary for: kkc.com
#     ✅ Summary: Rank=340, Backlinks=15,030
#     📄 Getting page rank for: https://kkc.com/
#     ✅ Page rank: 199
#     🔗 Getting backlinks sample for: kkc.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 340
#     Page Authority: 199
#     Backlinks Count: 15,030
#     Top Backlinks: 5
#     Referring Domains: 1111
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 454/656: dilendorf.com
# 🔄 Progress: 69.2%
#
#   🎯 ENRICHING: dilendorf.com
#   ==================================================
#     📊 Getting summary for: dilendorf.com
#     ✅ Summary: Rank=206, Backlinks=1,910
#     📄 Getting page rank for: https://dilendorf.com/
#     ✅ Page rank: 107
#     🔗 Getting backlinks sample for: dilendorf.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 206
#     Page Authority: 107
#     Backlinks Count: 1,910
#     Top Backlinks: 5
#     Referring Domains: 576
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 455/656: vondranlegal.com
# 🔄 Progress: 69.4%
#
#   🎯 ENRICHING: vondranlegal.com
#   ==================================================
#     📊 Getting summary for: vondranlegal.com
#     ✅ Summary: Rank=262, Backlinks=11,405
#     📄 Getting page rank for: https://vondranlegal.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: vondranlegal.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 262
#     Page Authority: 0
#     Backlinks Count: 11,405
#     Top Backlinks: 5
#     Referring Domains: 734
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 456/656: brownimmigrationlaw.com
# 🔄 Progress: 69.5%
#
#   🎯 ENRICHING: brownimmigrationlaw.com
#   ==================================================
#     📊 Getting summary for: brownimmigrationlaw.com
#     ✅ Summary: Rank=157, Backlinks=836
#     📄 Getting page rank for: https://brownimmigrationlaw.com/
#     ✅ Page rank: 141
#     🔗 Getting backlinks sample for: brownimmigrationlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 157
#     Page Authority: 141
#     Backlinks Count: 836
#     Top Backlinks: 5
#     Referring Domains: 176
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 457/656: jackson-hertogs.com
# 🔄 Progress: 69.7%
#
#   🎯 ENRICHING: jackson-hertogs.com
#   ==================================================
#     📊 Getting summary for: jackson-hertogs.com
#     ✅ Summary: Rank=156, Backlinks=648
#     📄 Getting page rank for: https://jackson-hertogs.com/
#     ✅ Page rank: 112
#     🔗 Getting backlinks sample for: jackson-hertogs.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 156
#     Page Authority: 112
#     Backlinks Count: 648
#     Top Backlinks: 5
#     Referring Domains: 305
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 458/656: usvisanet.com
# 🔄 Progress: 69.8%
#
#   🎯 ENRICHING: usvisanet.com
#   ==================================================
#     📊 Getting summary for: usvisanet.com
#     ✅ Summary: Rank=241, Backlinks=2,653
#     📄 Getting page rank for: https://usvisanet.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: usvisanet.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 241
#     Page Authority: 0
#     Backlinks Count: 2,653
#     Top Backlinks: 5
#     Referring Domains: 115
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 459/656: avlawoffice.com
# 🔄 Progress: 70.0%
#
#   🎯 ENRICHING: avlawoffice.com
#   ==================================================
#     📊 Getting summary for: avlawoffice.com
#     ✅ Summary: Rank=223, Backlinks=1,205
#     📄 Getting page rank for: https://avlawoffice.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: avlawoffice.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 223
#     Page Authority: 0
#     Backlinks Count: 1,205
#     Top Backlinks: 5
#     Referring Domains: 234
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 460/656: bayimmigrationlaw.com
# 🔄 Progress: 70.1%
#
#   🎯 ENRICHING: bayimmigrationlaw.com
#   ==================================================
#     📊 Getting summary for: bayimmigrationlaw.com
#     ✅ Summary: Rank=111, Backlinks=172
#     📄 Getting page rank for: https://bayimmigrationlaw.com/
#     ✅ Page rank: 99
#     🔗 Getting backlinks sample for: bayimmigrationlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 111
#     Page Authority: 99
#     Backlinks Count: 172
#     Top Backlinks: 5
#     Referring Domains: 73
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 461/656: reevesimmigration.com
# 🔄 Progress: 70.3%
#
#   🎯 ENRICHING: reevesimmigration.com
#   ==================================================
#     📊 Getting summary for: reevesimmigration.com
#     ✅ Summary: Rank=170, Backlinks=440
#     📄 Getting page rank for: https://reevesimmigration.com/
#     ✅ Page rank: 133
#     🔗 Getting backlinks sample for: reevesimmigration.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 170
#     Page Authority: 133
#     Backlinks Count: 440
#     Top Backlinks: 5
#     Referring Domains: 212
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 462/656: nasirilaw.com
# 🔄 Progress: 70.4%
#
#   🎯 ENRICHING: nasirilaw.com
#   ==================================================
#     📊 Getting summary for: nasirilaw.com
#     ✅ Summary: Rank=180, Backlinks=1,659
#     📄 Getting page rank for: https://nasirilaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: nasirilaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 180
#     Page Authority: 0
#     Backlinks Count: 1,659
#     Top Backlinks: 5
#     Referring Domains: 151
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 463/656: smcgov.org
# 🔄 Progress: 70.6%
#
#   🎯 ENRICHING: smcgov.org
#   ==================================================
#     📊 Getting summary for: smcgov.org
#     ✅ Summary: Rank=459, Backlinks=244,394
#     📄 Getting page rank for: https://smcgov.org/
#     ✅ Page rank: 149
#     🔗 Getting backlinks sample for: smcgov.org
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 459
#     Page Authority: 149
#     Backlinks Count: 244,394
#     Top Backlinks: 5
#     Referring Domains: 7038
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 464/656: jubileelegal.org
# 🔄 Progress: 70.7%
#
#   🎯 ENRICHING: jubileelegal.org
#   ==================================================
#     📊 Getting summary for: jubileelegal.org
#     ✅ Summary: Rank=171, Backlinks=325
#     📄 Getting page rank for: https://jubileelegal.org/
#     ✅ Page rank: 151
#     🔗 Getting backlinks sample for: jubileelegal.org
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 171
#     Page Authority: 151
#     Backlinks Count: 325
#     Top Backlinks: 5
#     Referring Domains: 78
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 465/656: desj.santaclaracounty.gov
# 🔄 Progress: 70.9%
#
#   🎯 ENRICHING: desj.santaclaracounty.gov
#   ==================================================
#     📊 Getting summary for: desj.santaclaracounty.gov
#     ✅ Summary: Rank=166, Backlinks=510
#     📄 Getting page rank for: https://desj.santaclaracounty.gov/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: desj.santaclaracounty.gov
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 166
#     Page Authority: 0
#     Backlinks Count: 510
#     Top Backlinks: 5
#     Referring Domains: 202
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 466/656: usavisalaw.com
# 🔄 Progress: 71.0%
#
#   🎯 ENRICHING: usavisalaw.com
#   ==================================================
#     📊 Getting summary for: usavisalaw.com
#     ✅ Summary: Rank=201, Backlinks=853
#     📄 Getting page rank for: https://usavisalaw.com/
#     ✅ Page rank: 96
#     🔗 Getting backlinks sample for: usavisalaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 201
#     Page Authority: 96
#     Backlinks Count: 853
#     Top Backlinks: 5
#     Referring Domains: 266
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 467/656: undocu.ucsf.edu
# 🔄 Progress: 71.2%
#
#   🎯 ENRICHING: undocu.ucsf.edu
#   ==================================================
#     📊 Getting summary for: undocu.ucsf.edu
#     ✅ Summary: Rank=78, Backlinks=74
#     📄 Getting page rank for: https://undocu.ucsf.edu/
#     ✅ Page rank: 39
#     🔗 Getting backlinks sample for: undocu.ucsf.edu
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 78
#     Page Authority: 39
#     Backlinks Count: 74
#     Top Backlinks: 5
#     Referring Domains: 61
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 468/656: immigrantcrime.com
# 🔄 Progress: 71.3%
#
#   🎯 ENRICHING: immigrantcrime.com
#   ==================================================
#     📊 Getting summary for: immigrantcrime.com
#     ✅ Summary: Rank=81, Backlinks=130
#     📄 Getting page rank for: https://immigrantcrime.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: immigrantcrime.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 81
#     Page Authority: 0
#     Backlinks Count: 130
#     Top Backlinks: 5
#     Referring Domains: 50
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 469/656: smossmanlaw.com
# 🔄 Progress: 71.5%
#
#   🎯 ENRICHING: smossmanlaw.com
#   ==================================================
#     📊 Getting summary for: smossmanlaw.com
#     ✅ Summary: Rank=99, Backlinks=353
#     📄 Getting page rank for: https://smossmanlaw.com/
#     ✅ Page rank: 51
#     🔗 Getting backlinks sample for: smossmanlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 99
#     Page Authority: 51
#     Backlinks Count: 353
#     Top Backlinks: 5
#     Referring Domains: 116
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 470/656: rosycholaw.com
# 🔄 Progress: 71.6%
#
#   🎯 ENRICHING: rosycholaw.com
#   ==================================================
#     📊 Getting summary for: rosycholaw.com
#     ✅ Summary: Rank=3, Backlinks=55
#     📄 Getting page rank for: https://rosycholaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: rosycholaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 3
#     Page Authority: 0
#     Backlinks Count: 55
#     Top Backlinks: 5
#     Referring Domains: 39
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 471/656: harrisonimmigration.com
# 🔄 Progress: 71.8%
#
#   🎯 ENRICHING: harrisonimmigration.com
#   ==================================================
#     📊 Getting summary for: harrisonimmigration.com
#     ✅ Summary: Rank=91, Backlinks=96
#     📄 Getting page rank for: https://harrisonimmigration.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: harrisonimmigration.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 91
#     Page Authority: 0
#     Backlinks Count: 96
#     Top Backlinks: 5
#     Referring Domains: 56
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 472/656: hafeykarim.com
# 🔄 Progress: 72.0%
#
#   🎯 ENRICHING: hafeykarim.com
#   ==================================================
#     📊 Getting summary for: hafeykarim.com
#     ✅ Summary: Rank=121, Backlinks=360
#     📄 Getting page rank for: https://hafeykarim.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: hafeykarim.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 121
#     Page Authority: 0
#     Backlinks Count: 360
#     Top Backlinks: 5
#     Referring Domains: 43
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 473/656: hirayaimmigration.com
# 🔄 Progress: 72.1%
#
#   🎯 ENRICHING: hirayaimmigration.com
#   ==================================================
#     📊 Getting summary for: hirayaimmigration.com
#     ✅ Summary: Rank=157, Backlinks=161
#     📄 Getting page rank for: https://hirayaimmigration.com/
#     ✅ Page rank: 67
#     🔗 Getting backlinks sample for: hirayaimmigration.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 157
#     Page Authority: 67
#     Backlinks Count: 161
#     Top Backlinks: 5
#     Referring Domains: 38
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 474/656: wileyjobson.com
# 🔄 Progress: 72.3%
#
#   🎯 ENRICHING: wileyjobson.com
#   ==================================================
#     📊 Getting summary for: wileyjobson.com
#     ✅ Summary: Rank=83, Backlinks=176
#     📄 Getting page rank for: https://wileyjobson.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: wileyjobson.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 83
#     Page Authority: 0
#     Backlinks Count: 176
#     Top Backlinks: 5
#     Referring Domains: 85
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 475/656: warrenlawfirm.net
# 🔄 Progress: 72.4%
#
#   🎯 ENRICHING: warrenlawfirm.net
#   ==================================================
#     📊 Getting summary for: warrenlawfirm.net
#     ✅ Summary: Rank=224, Backlinks=1,462
#     📄 Getting page rank for: https://warrenlawfirm.net/
#     ✅ Page rank: 114
#     🔗 Getting backlinks sample for: warrenlawfirm.net
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 224
#     Page Authority: 114
#     Backlinks Count: 1,462
#     Top Backlinks: 5
#     Referring Domains: 346
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 476/656: tilimmigration.com
# 🔄 Progress: 72.6%
#
#   🎯 ENRICHING: tilimmigration.com
#   ==================================================
#     📊 Getting summary for: tilimmigration.com
#     ✅ Summary: Rank=166, Backlinks=182
#     📄 Getting page rank for: https://tilimmigration.com/
#     ✅ Page rank: 157
#     🔗 Getting backlinks sample for: tilimmigration.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 166
#     Page Authority: 157
#     Backlinks Count: 182
#     Top Backlinks: 5
#     Referring Domains: 103
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 477/656: corporateimmigrationcounsel.com
# 🔄 Progress: 72.7%
#
#   🎯 ENRICHING: corporateimmigrationcounsel.com
#   ==================================================
#     📊 Getting summary for: corporateimmigrationcounsel.com
#     ✅ Summary: Rank=140, Backlinks=605
#     📄 Getting page rank for: https://corporateimmigrationcounsel.com/
#     ✅ Page rank: 83
#     🔗 Getting backlinks sample for: corporateimmigrationcounsel.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 140
#     Page Authority: 83
#     Backlinks Count: 605
#     Top Backlinks: 5
#     Referring Domains: 81
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 478/656: sanfranciscolawgroup.com
# 🔄 Progress: 72.9%
#
#   🎯 ENRICHING: sanfranciscolawgroup.com
#   ==================================================
#     📊 Getting summary for: sanfranciscolawgroup.com
#     ✅ Summary: Rank=91, Backlinks=114
#     📄 Getting page rank for: https://sanfranciscolawgroup.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: sanfranciscolawgroup.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 91
#     Page Authority: 0
#     Backlinks Count: 114
#     Top Backlinks: 5
#     Referring Domains: 46
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 479/656: litwinlaw.com
# 🔄 Progress: 73.0%
#
#   🎯 ENRICHING: litwinlaw.com
#   ==================================================
#     📊 Getting summary for: litwinlaw.com
#     ✅ Summary: Rank=180, Backlinks=908
#     📄 Getting page rank for: https://litwinlaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: litwinlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 180
#     Page Authority: 0
#     Backlinks Count: 908
#     Top Backlinks: 5
#     Referring Domains: 252
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 480/656: sacattorneys.com
# 🔄 Progress: 73.2%
#
#   🎯 ENRICHING: sacattorneys.com
#   ==================================================
#     📊 Getting summary for: sacattorneys.com
#     ✅ Summary: Rank=232, Backlinks=11,298
#     📄 Getting page rank for: https://sacattorneys.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: sacattorneys.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 232
#     Page Authority: 0
#     Backlinks Count: 11,298
#     Top Backlinks: 5
#     Referring Domains: 470
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 481/656: centrolegal.org
# 🔄 Progress: 73.3%
#
#   🎯 ENRICHING: centrolegal.org
#   ==================================================
#     📊 Getting summary for: centrolegal.org
#     ✅ Summary: Rank=244, Backlinks=2,942
#     📄 Getting page rank for: https://centrolegal.org/
#     ✅ Page rank: 150
#     🔗 Getting backlinks sample for: centrolegal.org
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 244
#     Page Authority: 150
#     Backlinks Count: 2,942
#     Top Backlinks: 5
#     Referring Domains: 904
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 482/656: troylaw.net
# 🔄 Progress: 73.5%
#
#   🎯 ENRICHING: troylaw.net
#   ==================================================
#     📊 Getting summary for: troylaw.net
#     ✅ Summary: Rank=218, Backlinks=1,115
#     📄 Getting page rank for: https://troylaw.net/
#     ✅ Page rank: 7
#     🔗 Getting backlinks sample for: troylaw.net
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 218
#     Page Authority: 7
#     Backlinks Count: 1,115
#     Top Backlinks: 5
#     Referring Domains: 154
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 483/656: schneiderwallace.com
# 🔄 Progress: 73.6%
#
#   🎯 ENRICHING: schneiderwallace.com
#   ==================================================
#     📊 Getting summary for: schneiderwallace.com
#     ✅ Summary: Rank=205, Backlinks=6,699
#     📄 Getting page rank for: https://schneiderwallace.com/
#     ✅ Page rank: 49
#     🔗 Getting backlinks sample for: schneiderwallace.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 205
#     Page Authority: 49
#     Backlinks Count: 6,699
#     Top Backlinks: 5
#     Referring Domains: 293
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 484/656: pmrklaw.com
# 🔄 Progress: 73.8%
#
#   🎯 ENRICHING: pmrklaw.com
#   ==================================================
#     📊 Getting summary for: pmrklaw.com
#     ✅ Summary: Rank=55, Backlinks=389
#     📄 Getting page rank for: https://pmrklaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: pmrklaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 55
#     Page Authority: 0
#     Backlinks Count: 389
#     Top Backlinks: 5
#     Referring Domains: 28
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 485/656: tong-law.com
# 🔄 Progress: 73.9%
#
#   🎯 ENRICHING: tong-law.com
#   ==================================================
#     📊 Getting summary for: tong-law.com
#     ✅ Summary: Rank=232, Backlinks=4,325
#     📄 Getting page rank for: https://tong-law.com/
#     ✅ Page rank: 0
# ...
#     ✅ Summary: Rank=402, Backlinks=54,713
#     📄 Getting page rank for: https://moseleycollins.com/
#     ✅ Page rank: 29
#     🔗 Getting backlinks sample for: moseleycollins.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 402
#     Page Authority: 29
#     Backlinks Count: 54,713
#     Top Backlinks: 5
#     Referring Domains: 4402
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 631/656: sanfranciscobestcriminallawyer.com
# 🔄 Progress: 96.2%
#
#   🎯 ENRICHING: sanfranciscobestcriminallawyer.com
#   ==================================================
#     📊 Getting summary for: sanfranciscobestcriminallawyer.com
#     ✅ Summary: Rank=103, Backlinks=61
#     📄 Getting page rank for: https://sanfranciscobestcriminallawyer.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: sanfranciscobestcriminallawyer.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 103
#     Page Authority: 0
#     Backlinks Count: 61
#     Top Backlinks: 5
#     Referring Domains: 37
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 632/656: greenbergrubylaw.com
# 🔄 Progress: 96.3%
#
#   🎯 ENRICHING: greenbergrubylaw.com
#   ==================================================
#     📊 Getting summary for: greenbergrubylaw.com
#     ✅ Summary: Rank=212, Backlinks=943
#     📄 Getting page rank for: https://greenbergrubylaw.com/
#     ✅ Page rank: 3
#     🔗 Getting backlinks sample for: greenbergrubylaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 212
#     Page Authority: 3
#     Backlinks Count: 943
#     Top Backlinks: 5
#     Referring Domains: 345
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 633/656: californiabirthinjurylawfirm.com
# 🔄 Progress: 96.5%
#
#   🎯 ENRICHING: californiabirthinjurylawfirm.com
#   ==================================================
#     📊 Getting summary for: californiabirthinjurylawfirm.com
#     ✅ Summary: Rank=2, Backlinks=68
#     📄 Getting page rank for: https://californiabirthinjurylawfirm.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: californiabirthinjurylawfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 2
#     Page Authority: 0
#     Backlinks Count: 68
#     Top Backlinks: 5
#     Referring Domains: 29
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 634/656: mitchell-leeds.com
# 🔄 Progress: 96.6%
#
#   🎯 ENRICHING: mitchell-leeds.com
#   ==================================================
#     📊 Getting summary for: mitchell-leeds.com
#     ✅ Summary: Rank=154, Backlinks=378
#     📄 Getting page rank for: https://mitchell-leeds.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: mitchell-leeds.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 154
#     Page Authority: 0
#     Backlinks Count: 378
#     Top Backlinks: 5
#     Referring Domains: 64
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 635/656: mbc.ca.gov
# 🔄 Progress: 96.8%
#
#   🎯 ENRICHING: mbc.ca.gov
#   ==================================================
#     📊 Getting summary for: mbc.ca.gov
#     ✅ Summary: Rank=211, Backlinks=12,567
#     📄 Getting page rank for: https://mbc.ca.gov/
#     ✅ Page rank: 103
#     🔗 Getting backlinks sample for: mbc.ca.gov
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 211
#     Page Authority: 103
#     Backlinks Count: 12,567
#     Top Backlinks: 5
#     Referring Domains: 521
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 636/656: bennettmcohen.com
# 🔄 Progress: 97.0%
#
#   🎯 ENRICHING: bennettmcohen.com
#   ==================================================
#     📊 Getting summary for: bennettmcohen.com
#     ✅ Summary: Rank=150, Backlinks=263
#     📄 Getting page rank for: https://bennettmcohen.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: bennettmcohen.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 150
#     Page Authority: 0
#     Backlinks Count: 263
#     Top Backlinks: 5
#     Referring Domains: 82
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 637/656: pintas.com
# 🔄 Progress: 97.1%
#
#   🎯 ENRICHING: pintas.com
#   ==================================================
#     📊 Getting summary for: pintas.com
#     ✅ Summary: Rank=339, Backlinks=16,708
#     📄 Getting page rank for: https://pintas.com/
#     ✅ Page rank: 58
#     🔗 Getting backlinks sample for: pintas.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 339
#     Page Authority: 58
#     Backlinks Count: 16,708
#     Top Backlinks: 5
#     Referring Domains: 2544
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 638/656: anderlinimcsweeneylaw.com
# 🔄 Progress: 97.3%
#
#   🎯 ENRICHING: anderlinimcsweeneylaw.com
#   ==================================================
#     📊 Getting summary for: anderlinimcsweeneylaw.com
#     ✅ Summary: Rank=0, Backlinks=196
#     📄 Getting page rank for: https://anderlinimcsweeneylaw.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: anderlinimcsweeneylaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 0
#     Page Authority: 0
#     Backlinks Count: 196
#     Top Backlinks: 5
#     Referring Domains: 156
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 639/656: willoughbyfirm.com
# 🔄 Progress: 97.4%
#
#   🎯 ENRICHING: willoughbyfirm.com
#   ==================================================
#     📊 Getting summary for: willoughbyfirm.com
#     ✅ Summary: Rank=33, Backlinks=129
#     📄 Getting page rank for: https://willoughbyfirm.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: willoughbyfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 33
#     Page Authority: 0
#     Backlinks Count: 129
#     Top Backlinks: 5
#     Referring Domains: 66
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 640/656: donahuehorrow.com
# 🔄 Progress: 97.6%
#
#   🎯 ENRICHING: donahuehorrow.com
#   ==================================================
#     📊 Getting summary for: donahuehorrow.com
#     ✅ Summary: Rank=261, Backlinks=1,777
#     📄 Getting page rank for: https://donahuehorrow.com/
#     ✅ Page rank: 73
#     🔗 Getting backlinks sample for: donahuehorrow.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 261
#     Page Authority: 73
#     Backlinks Count: 1,777
#     Top Backlinks: 5
#     Referring Domains: 298
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 641/656: kornblumlaw.com
# 🔄 Progress: 97.7%
#
#   🎯 ENRICHING: kornblumlaw.com
#   ==================================================
#     📊 Getting summary for: kornblumlaw.com
#     ✅ Summary: Rank=197, Backlinks=4,772
#     📄 Getting page rank for: https://kornblumlaw.com/
#     ✅ Page rank: 144
#     🔗 Getting backlinks sample for: kornblumlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 197
#     Page Authority: 144
#     Backlinks Count: 4,772
#     Top Backlinks: 5
#     Referring Domains: 114
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 642/656: lessergroup.com
# 🔄 Progress: 97.9%
#
#   🎯 ENRICHING: lessergroup.com
#   ==================================================
#     📊 Getting summary for: lessergroup.com
#     ✅ Summary: Rank=145, Backlinks=973
#     📄 Getting page rank for: https://lessergroup.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: lessergroup.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 145
#     Page Authority: 0
#     Backlinks Count: 973
#     Top Backlinks: 5
#     Referring Domains: 87
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 643/656: righthandfirm.com
# 🔄 Progress: 98.0%
#
#   🎯 ENRICHING: righthandfirm.com
#   ==================================================
#     📊 Getting summary for: righthandfirm.com
#     ✅ Summary: Rank=239, Backlinks=2,867
#     📄 Getting page rank for: https://righthandfirm.com/
#     ✅ Page rank: 29
#     🔗 Getting backlinks sample for: righthandfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 239
#     Page Authority: 29
#     Backlinks Count: 2,867
#     Top Backlinks: 5
#     Referring Domains: 359
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 644/656: ggu.edu
# 🔄 Progress: 98.2%
#
#   🎯 ENRICHING: ggu.edu
#   ==================================================
#     📊 Getting summary for: ggu.edu
#     ✅ Summary: Rank=376, Backlinks=140,209
#     📄 Getting page rank for: https://ggu.edu/
#     ✅ Page rank: 204
#     🔗 Getting backlinks sample for: ggu.edu
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 376
#     Page Authority: 204
#     Backlinks Count: 140,209
#     Top Backlinks: 5
#     Referring Domains: 5921
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 645/656: hunton.com
# 🔄 Progress: 98.3%
#
#   🎯 ENRICHING: hunton.com
#   ==================================================
#     📊 Getting summary for: hunton.com
#     ✅ Summary: Rank=342, Backlinks=150,680
#     📄 Getting page rank for: https://hunton.com/
#     ✅ Page rank: 205
#     🔗 Getting backlinks sample for: hunton.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 342
#     Page Authority: 205
#     Backlinks Count: 150,680
#     Top Backlinks: 5
#     Referring Domains: 5349
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 646/656: kaplankirsch.com
# 🔄 Progress: 98.5%
#
#   🎯 ENRICHING: kaplankirsch.com
#   ==================================================
#     📊 Getting summary for: kaplankirsch.com
#     ✅ Summary: Rank=211, Backlinks=1,327
#     📄 Getting page rank for: https://kaplankirsch.com/
#     ✅ Page rank: 156
#     🔗 Getting backlinks sample for: kaplankirsch.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 211
#     Page Authority: 156
#     Backlinks Count: 1,327
#     Top Backlinks: 5
#     Referring Domains: 311
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 647/656: crowell.com
# 🔄 Progress: 98.6%
#
#   🎯 ENRICHING: crowell.com
#   ==================================================
#     📊 Getting summary for: crowell.com
#     ✅ Summary: Rank=418, Backlinks=95,150
#     📄 Getting page rank for: https://crowell.com/
#     ✅ Page rank: 238
#     🔗 Getting backlinks sample for: crowell.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 418
#     Page Authority: 238
#     Backlinks Count: 95,150
#     Top Backlinks: 5
#     Referring Domains: 5338
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 648/656: maternlawgroup.com
# 🔄 Progress: 98.8%
#
#   🎯 ENRICHING: maternlawgroup.com
#   ==================================================
#     📊 Getting summary for: maternlawgroup.com
#     ✅ Summary: Rank=219, Backlinks=686
#     📄 Getting page rank for: https://maternlawgroup.com/
#     ✅ Page rank: 47
#     🔗 Getting backlinks sample for: maternlawgroup.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 219
#     Page Authority: 47
#     Backlinks Count: 686
#     Top Backlinks: 5
#     Referring Domains: 363
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 649/656: egcounsel.com
# 🔄 Progress: 98.9%
#
#   🎯 ENRICHING: egcounsel.com
#   ==================================================
#     📊 Getting summary for: egcounsel.com
#     ✅ Summary: Rank=120, Backlinks=127
#     📄 Getting page rank for: https://egcounsel.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: egcounsel.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 120
#     Page Authority: 0
#     Backlinks Count: 127
#     Top Backlinks: 5
#     Referring Domains: 69
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 650/656: bwslaw.com
# 🔄 Progress: 99.1%
#
#   🎯 ENRICHING: bwslaw.com
#   ==================================================
#     📊 Getting summary for: bwslaw.com
#     ✅ Summary: Rank=332, Backlinks=8,001
#     📄 Getting page rank for: https://bwslaw.com/
#     ✅ Page rank: 145
#     🔗 Getting backlinks sample for: bwslaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 332
#     Page Authority: 145
#     Backlinks Count: 8,001
#     Top Backlinks: 5
#     Referring Domains: 888
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 651/656: bargcoffin.com
# 🔄 Progress: 99.2%
#
#   🎯 ENRICHING: bargcoffin.com
#   ==================================================
#     📊 Getting summary for: bargcoffin.com
#     ✅ Summary: Rank=232, Backlinks=3,491
#     📄 Getting page rank for: https://bargcoffin.com/
#     ✅ Page rank: 21
#     🔗 Getting backlinks sample for: bargcoffin.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 232
#     Page Authority: 21
#     Backlinks Count: 3,491
#     Top Backlinks: 5
#     Referring Domains: 110
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 652/656: levylaw.com
# 🔄 Progress: 99.4%
#
#   🎯 ENRICHING: levylaw.com
#   ==================================================
#     📊 Getting summary for: levylaw.com
#     ✅ Summary: Rank=283, Backlinks=15,342
#     📄 Getting page rank for: https://levylaw.com/
#     ✅ Page rank: 88
#     🔗 Getting backlinks sample for: levylaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 283
#     Page Authority: 88
#     Backlinks Count: 15,342
#     Top Backlinks: 5
#     Referring Domains: 649
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 653/656: robertkinglawfirm.com
# 🔄 Progress: 99.5%
#
#   🎯 ENRICHING: robertkinglawfirm.com
#   ==================================================
#     📊 Getting summary for: robertkinglawfirm.com
#     ✅ Summary: Rank=274, Backlinks=5,742
#     📄 Getting page rank for: https://robertkinglawfirm.com/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: robertkinglawfirm.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 274
#     Page Authority: 0
#     Backlinks Count: 5,742
#     Top Backlinks: 5
#     Referring Domains: 985
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 654/656: watercontaminationlawsuits.com
# 🔄 Progress: 99.7%
#
#   🎯 ENRICHING: watercontaminationlawsuits.com
#   ==================================================
#     📊 Getting summary for: watercontaminationlawsuits.com
#     ✅ Summary: Rank=215, Backlinks=177
#     📄 Getting page rank for: https://watercontaminationlawsuits.com/
#     ✅ Page rank: 158
#     🔗 Getting backlinks sample for: watercontaminationlawsuits.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 215
#     Page Authority: 158
#     Backlinks Count: 177
#     Top Backlinks: 5
#     Referring Domains: 151
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 655/656: pbp.law
# 🔄 Progress: 99.8%
#
#   🎯 ENRICHING: pbp.law
#   ==================================================
#     📊 Getting summary for: pbp.law
#     ✅ Summary: Rank=0, Backlinks=30
#     📄 Getting page rank for: https://pbp.law/
#     ✅ Page rank: 0
#     🔗 Getting backlinks sample for: pbp.law
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 0
#     Page Authority: 0
#     Backlinks Count: 30
#     Top Backlinks: 5
#     Referring Domains: 16
#   💤 Waiting 3 seconds...
#
# 📍 DOMAIN 656/656: arashlaw.com
# 🔄 Progress: 100.0%
#
#   🎯 ENRICHING: arashlaw.com
#   ==================================================
#     📊 Getting summary for: arashlaw.com
#     ✅ Summary: Rank=344, Backlinks=21,961
#     📄 Getting page rank for: https://arashlaw.com/
#     ✅ Page rank: 229
#     🔗 Getting backlinks sample for: arashlaw.com
#     ✅ Found 5 sample backlinks
#   📊 RESULTS:
#     Domain Authority: 344
#     Page Authority: 229
#     Backlinks Count: 21,961
#     Top Backlinks: 5
#     Referring Domains: 2290
#
# 📋 APPLYING RESULTS TO DATAFRAME...
#
# 🎉 TOP10 COMPLETE ENRICHMENT FINISHED!
# ================================================================================
# 💾 Saved to: San_Francisco_top10_COMPLETE_enriched.csv
# 📊 STATISTICS:
#   📈 Total backlinks: 262,212,046,927
#   🎯 Rows with backlinks: 5,877/5,877
#   🏆 Max backlinks: 3,471,995,831
#   🏅 Max domain authority: 815
#   🏅 Max page authority: 534
#   💰 Actual cost: $39.36
#
# 🎉 SAN FRANCISCO COMPLETE ENRICHMENT FINISHED!
# ====================================================================================================
# ✅ TOP3: 1,633 rows, 246 domains enriched
# ✅ TOP10: 5,877 rows, 656 domains enriched
#
# 📊 FINAL STATISTICS:
# 🔧 Total API calls made: 2706
# 💰 Actual total cost: ~$54.12
# 📂 Output location: /content/drive/MyDrive/Part 2/San Francisco/
# 📄 Generated files:
#   - San_Francisco_top3_COMPLETE_enriched.csv
#   - San_Francisco_top10_COMPLETE_enriched.csv
#
# 🏆 TOP PERFORMING DOMAINS ANALYSIS:
#
# 🔗 Top 5 by Backlinks:
#   1. reddit.com: 3,471,995,831 backlinks
#   2. pubmed.ncbi.nlm.nih.gov: 604,891,232 backlinks
#   3. quora.com: 448,518,784 backlinks
#   4. bbb.org: 235,181,322 backlinks
#   5. irs.gov: 46,344,147 backlinks
#
# 🏅 Top 5 by Domain Authority:
#   1. reddit.com: 815 authority
#   2. bbb.org: 749 authority
#   3. irs.gov: 670 authority
#   4. justice.gov: 614 authority
#   5. jamsadr.com: 598 authority
#
# ✨ COMPLETE ENRICHMENT SUCCESSFUL!
# 🎯 ALL METRICS POPULATED: Domain Authority, Page Authority, Trust Flow, Backlinks!

# %%
#Moz API
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import requests
import base64
import time
import json
from urllib.parse import urlparse
from datetime import datetime, timezone

# === Moz API 认证信息 ===
MOZ_ACCESS_ID = "mozscape-pn863y8erR"
MOZ_SECRET_KEY = "CpBLhVJlFaCEe9EPQkOoLjO6UF0iKUUf"

# === 路径设置 ===
BASE_PATH = "/content/drive/MyDrive/Part 2"
OUTPUT_BASE_PATH = "/content/drive/MyDrive/Part 2/Moz_Enriched_Results"

# 创建输出目录
os.makedirs(OUTPUT_BASE_PATH, exist_ok=True)

def extract_domain(url):
    """提取域名"""
    try:
        return urlparse(url).netloc.replace("www.", "")
    except:
        return None

def safe_join_backlinks(domain, moz_results):
    """安全地连接backlinks数据"""
    try:
        backlinks = moz_results.get(domain, {}).get("top_backlinks", [])
        if not backlinks:
            return ""

        # 确保所有元素都是字符串
        str_backlinks = []
        for link in backlinks:
            if isinstance(link, str):
                str_backlinks.append(link)
            elif isinstance(link, dict):
                # 如果是字典，尝试提取URL
                url = link.get('source', '') or link.get('url', '') or str(link)
                str_backlinks.append(url)
            else:
                str_backlinks.append(str(link))

        return "; ".join(str_backlinks)
    except Exception as e:
        print(f"    ⚠️ Error processing backlinks for {domain}: {e}")
        return ""

def get_moz_url_metrics(urls_batch):
    """获取Moz URL指标"""
    endpoint = "https://lsapi.seomoz.com/v2/url_metrics"

    headers = {
        "Authorization": f"Basic {base64.b64encode(f'{MOZ_ACCESS_ID}:{MOZ_SECRET_KEY}'.encode()).decode()}",
        "Content-Type": "application/json"
    }

    payload = {
        "targets": urls_batch
    }

    try:
        print(f"    🔍 Requesting Moz data for {len(urls_batch)} URLs...")

        response = requests.post(endpoint, headers=headers, json=payload)

        print(f"    📊 Response status: {response.status_code}")

        if response.status_code == 200:
            data = response.json()
            print(f"    ✅ Got data for {len(data.get('results', []))} URLs")
            return data.get('results', [])
        else:
            print(f"    ❌ Error: {response.status_code} - {response.text}")
            return []

    except Exception as e:
        print(f"    ❌ Exception: {e}")
        return []

def process_moz_results(moz_results):
    """处理Moz API返回的结果"""
    processed_data = {}

    for result in moz_results:
        domain = result.get('root_domain')

        if domain:
            processed_data[domain] = {
                'domain_authority': result.get('domain_authority', 0),
                'page_authority': result.get('page_authority', 0),
                'spam_score': result.get('spam_score', 0),
                'root_domains_to_root_domain': result.get('root_domains_to_root_domain', 0),
                'external_pages_to_root_domain': result.get('external_pages_to_root_domain', 0),
                'pages_to_root_domain': result.get('pages_to_root_domain', 0),
                'top_backlinks': []  # 初始化为空列表
            }

    return processed_data

def enrich_domains_with_moz(domains_list, city_name, batch_size=10):
    """使用Moz API批量enrichment域名"""
    print(f"  📊 Moz enrichment for {len(domains_list)} domains in {city_name}")

    # 准备URL列表
    urls_to_process = []
    for domain in domains_list:
        if domain and domain.strip():
            url = f"https://{domain.strip()}/"
            urls_to_process.append(url)

    print(f"  🎯 Processing {len(urls_to_process)} URLs in batches of {batch_size}")

    all_results = {}
    total_batches = (len(urls_to_process) + batch_size - 1) // batch_size

    for i in range(0, len(urls_to_process), batch_size):
        batch_urls = urls_to_process[i:i + batch_size]
        batch_num = (i // batch_size) + 1

        print(f"\n  📦 Batch {batch_num}/{total_batches}: {len(batch_urls)} URLs")

        # 获取URL metrics
        moz_results = get_moz_url_metrics(batch_urls)

        if moz_results:
            processed_results = process_moz_results(moz_results)
            all_results.update(processed_results)

            # 显示批次结果（前5个）
            shown = 0
            for domain, data in processed_results.items():
                if shown < 5:  # 只显示前5个以节省空间
                    da = data['domain_authority']
                    pa = data['page_authority']
                    backlinks = data['external_pages_to_root_domain']
                    print(f"    ✅ {domain}: DA={da}, PA={pa}, Backlinks={backlinks:,}")
                    shown += 1

            if len(processed_results) > 5:
                print(f"    ... and {len(processed_results) - 5} more domains")

        # API限制延迟
        if batch_num < total_batches:
            print(f"    💤 Waiting 2 seconds...")
            time.sleep(2)

    # 为其他域名设置空的backlinks列表
    for domain in all_results:
        if 'top_backlinks' not in all_results[domain]:
            all_results[domain]['top_backlinks'] = []

    return all_results

def process_sf_file_complete(file_type="top3"):
    """处理San Francisco完整文件"""
    print(f"\n🌉 Processing San Francisco {file_type.upper()} - COMPLETE VERSION")
    print("=" * 80)

    # 构建文件路径
    if file_type == "top3":
        file_pattern = "top_3_results_filtered.csv"
    else:
        file_pattern = "top_10_results_filtered.csv"

    file_path = os.path.join(BASE_PATH, "San Francisco", file_pattern)

    if not os.path.exists(file_path):
        print(f"❌ File not found: {file_path}")
        return None

    try:
        # 读取数据
        df = pd.read_csv(file_path)
        print(f"📄 Loaded {len(df)} rows from {file_type}")

        # 提取域名
        df["domain"] = df["link"].apply(extract_domain)
        unique_domains = df["domain"].dropna().unique()

        print(f"🌐 Found {len(unique_domains)} unique domains")
        print(f"💰 Estimated cost: ${len(unique_domains) * 0.01:.2f}")
        print(f"⏱️ Estimated time: {len(unique_domains) * 0.2 / 60:.1f} minutes")

        # 显示前几个域名
        print(f"🔝 Sample domains: {list(unique_domains[:5])}")

        # Moz enrichment
        moz_results = enrich_domains_with_moz(unique_domains, f"San Francisco {file_type}")

        # 应用结果到dataframe
        print(f"\n📋 Applying Moz results to dataframe...")

        df["domain_authority"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("domain_authority", 0))
        df["page_authority"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("page_authority", 0))
        df["spam_score"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("spam_score", 0))
        df["backlinks_count"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("external_pages_to_root_domain", 0))
        df["referring_domains"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("root_domains_to_root_domain", 0))
        df["pages_to_domain"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("pages_to_root_domain", 0))
        df["top_backlinks"] = df["domain"].map(lambda d: safe_join_backlinks(d, moz_results))
        df["trust_flow"] = None  # Moz不提供Trust Flow

        # 保存结果
        output_filename = f"San_Francisco_{file_type}_moz_enriched.csv"
        output_path = os.path.join(OUTPUT_BASE_PATH, output_filename)
        df.to_csv(output_path, index=False)

        # 统计报告
        enriched_rows = (df["domain_authority"] > 0).sum()
        max_da = df["domain_authority"].max()
        avg_da = df[df["domain_authority"] > 0]["domain_authority"].mean()
        max_backlinks = df["backlinks_count"].max()
        total_backlinks = df["backlinks_count"].sum()

        print(f"\n📊 {file_type.upper()} Results Summary:")
        print(f"💾 Saved: {output_filename}")
        print(f"📈 Enriched rows: {enriched_rows:,}/{len(df):,}")
        print(f"🏆 Max Domain Authority: {max_da}")
        print(f"📊 Avg Domain Authority: {avg_da:.1f}")
        print(f"🔗 Max Backlinks: {max_backlinks:,}")
        print(f"📊 Total Backlinks: {total_backlinks:,}")
        print(f"💰 Actual cost: ~${len(unique_domains) * 0.01:.2f}")

        return df, moz_results

    except Exception as e:
        print(f"❌ Error processing San Francisco {file_type}: {e}")
        import traceback
        traceback.print_exc()
        return None

def main():
    """主函数 - 处理San Francisco完整数据"""
    print("🌉 San Francisco Complete Moz Enrichment System")
    print("=" * 100)
    print("🎯 Processing San Francisco TOP3 and TOP10 files")
    print("📊 Will generate 2 separate enriched CSV files")

    results_summary = {}
    total_cost = 0
    total_domains = 0

    # 处理TOP3文件
    print(f"\n🚀 Starting TOP3 enrichment...")
    top3_result = process_sf_file_complete("top3")

    if top3_result:
        df3, moz3 = top3_result
        results_summary["top3"] = {
            "status": "Success",
            "rows": len(df3),
            "domains_processed": len(moz3),
            "max_da": df3["domain_authority"].max(),
            "total_backlinks": df3["backlinks_count"].sum()
        }
        total_cost += len(moz3) * 0.01
        total_domains += len(moz3)
    else:
        results_summary["top3"] = {"status": "Failed"}

    # 延迟后处理TOP10文件
    print(f"\n💤 Waiting 5 seconds before TOP10...")
    time.sleep(5)

    print(f"\n🚀 Starting TOP10 enrichment...")
    top10_result = process_sf_file_complete("top10")

    if top10_result:
        df10, moz10 = top10_result
        results_summary["top10"] = {
            "status": "Success",
            "rows": len(df10),
            "domains_processed": len(moz10),
            "max_da": df10["domain_authority"].max(),
            "total_backlinks": df10["backlinks_count"].sum()
        }
        total_cost += len(moz10) * 0.01
        total_domains += len(moz10)
    else:
        results_summary["top10"] = {"status": "Failed"}

    # 最终报告
    print(f"\n🎉 San Francisco Complete Enrichment Finished!")
    print("=" * 100)

    for file_type, result in results_summary.items():
        if result["status"] == "Success":
            print(f"✅ {file_type.upper()}: {result['rows']:,} rows, {result['domains_processed']} domains")
            print(f"   Max DA: {result['max_da']}, Total Backlinks: {result['total_backlinks']:,}")
        else:
            print(f"❌ {file_type.upper()}: Failed")

    print(f"\n📊 Final Statistics:")
    print(f"🌐 Total unique domains processed: {total_domains}")
    print(f"💰 Total cost: ~${total_cost:.2f}")
    print(f"📂 Output files saved to: {OUTPUT_BASE_PATH}")
    print(f"📄 Generated files:")
    print(f"  - San_Francisco_top3_moz_enriched.csv")
    print(f"  - San_Francisco_top10_moz_enriched.csv")

    # 域名分析汇总
    if top3_result and top10_result:
        print(f"\n🏆 Top Performing Domains Analysis:")

        # 合并结果找出最高DA域名
        all_domains = {}
        all_domains.update(moz3)
        all_domains.update(moz10)

        # 按DA排序
        sorted_by_da = sorted(all_domains.items(), key=lambda x: x[1]["domain_authority"], reverse=True)

        print(f"🥇 Top 5 by Domain Authority:")
        for i, (domain, data) in enumerate(sorted_by_da[:5]):
            da = data['domain_authority']
            pa = data['page_authority']
            backlinks = data['external_pages_to_root_domain']
            print(f"  {i+1}. {domain}: DA={da}, PA={pa}, Backlinks={backlinks:,}")

    print(f"\n✨ San Francisco enrichment completed successfully!")
    print(f"🎯 Ready for analysis with complete Domain Authority and Page Authority data!")

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🌉 San Francisco Complete Moz Enrichment System
# ====================================================================================================
# 🎯 Processing San Francisco TOP3 and TOP10 files
# 📊 Will generate 2 separate enriched CSV files
#
# 🚀 Starting TOP3 enrichment...
#
# 🌉 Processing San Francisco TOP3 - COMPLETE VERSION
# ================================================================================
# 📄 Loaded 1633 rows from top3
# 🌐 Found 246 unique domains
# 💰 Estimated cost: $2.46
# ⏱️ Estimated time: 0.8 minutes
# 🔝 Sample domains: ['tslo.com', 'eastbaybusinesslawyer.com', 'sfbar.org', 'coblentzlaw.com', 'lscarlsonlaw.com']
#   📊 Moz enrichment for 246 domains in San Francisco top3
#   🎯 Processing 246 URLs in batches of 10
#
#   📦 Batch 1/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ tslo.com: DA=25, PA=25, Backlinks=5,275
#     ✅ eastbaybusinesslawyer.com: DA=12, PA=24, Backlinks=177
#     ✅ sfbar.org: DA=52, PA=45, Backlinks=52,412
#     ✅ coblentzlaw.com: DA=33, PA=36, Backlinks=8,282
#     ✅ lscarlsonlaw.com: DA=21, PA=34, Backlinks=1,530
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 2/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ imaginelaw.com: DA=19, PA=27, Backlinks=6,134
#     ✅ fenwick.com: DA=58, PA=50, Backlinks=137,912
#     ✅ bcgsearch.com: DA=49, PA=49, Backlinks=1,721,040
#     ✅ minamitamaki.com: DA=37, PA=35, Backlinks=2,536
#     ✅ adlercolvin.com: DA=42, PA=36, Backlinks=4,977
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 3/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ opendoorlegal.org: DA=29, PA=35, Backlinks=846
#     ✅ baylegal.org: DA=42, PA=47, Backlinks=92,568
#     ✅ wolfflaw.com: DA=22, PA=33, Backlinks=11,716
#     ✅ rftmlaw.com: DA=29, PA=36, Backlinks=3,501
#     ✅ jonesclifford.com: DA=18, PA=31, Backlinks=1,499
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 4/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ernestbrown.com: DA=19, PA=26, Backlinks=263
#     ✅ lunskilaw.com: DA=11, PA=21, Backlinks=90
#     ✅ valerynechaylaw.com: DA=22, PA=39, Backlinks=2,624
#     ✅ sanfranciscoduidefense.com: DA=16, PA=26, Backlinks=740
#     ✅ burglin.com: DA=19, PA=30, Backlinks=5,797
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 5/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ attorneys.media: DA=39, PA=40, Backlinks=10,729
#     ✅ gibbonslawyers.com: DA=23, PA=30, Backlinks=981
#     ✅ hallinanlawfirm.com: DA=15, PA=30, Backlinks=2,973
#     ✅ bortelduidefense.com: DA=23, PA=30, Backlinks=1,172
#     ✅ shouselaw.com: DA=60, PA=53, Backlinks=361,427
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 6/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ crownllp.com: DA=15, PA=25, Backlinks=178
#     ✅ lawyerforseniors.com: DA=23, PA=31, Backlinks=6,941
#     ✅ freedmanlawfirm.com: DA=23, PA=25, Backlinks=1,996
#     ✅ sfgate.com: DA=93, PA=71, Backlinks=41,445,886
#     ✅ ca.gov: DA=93, PA=61, Backlinks=329,462,764
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 7/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ shamiehlawsf.com: DA=16, PA=30, Backlinks=304
#     ✅ immigrate-us.net: DA=17, PA=31, Backlinks=3,158
#     ✅ kpbimmigrationlawfirm.com: DA=26, PA=34, Backlinks=8,120
#     ✅ sf.gov: DA=74, PA=58, Backlinks=1,963,984
#     ✅ huwelaw.com: DA=15, PA=27, Backlinks=454
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 8/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sackettlaw.com: DA=22, PA=32, Backlinks=1,772
#     ✅ ssdisabilityaccess.com: DA=21, PA=36, Backlinks=2,298
#     ✅ pillsburycoleman.com: DA=29, PA=34, Backlinks=10,055
#     ✅ andalmanflynn.com: DA=32, PA=39, Backlinks=5,189
#     ✅ prcsf.org: DA=40, PA=41, Backlinks=6,694
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 9/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ oneil.legal: DA=10, PA=22, Backlinks=584
#     ✅ specialneedsanswers.com: DA=47, PA=45, Backlinks=19,576
#     ✅ ahdlaws.com: DA=9, PA=21, Backlinks=37
#     ✅ mattsullivanlaw.com: DA=19, PA=27, Backlinks=2,070
#     ✅ bayareacrimlaw.com: DA=25, PA=31, Backlinks=732
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 10/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ federal-lawyer.com: DA=40, PA=49, Backlinks=24,594
#     ✅ lccrsf.org: DA=44, PA=41, Backlinks=2,665
#     ✅ buchalter.com: DA=45, PA=43, Backlinks=89,332
#     ✅ stoel.com: DA=51, PA=47, Backlinks=142,533
#     ✅ davis-stirling.com: DA=41, PA=46, Backlinks=90,680
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 11/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ paolinimori.com: DA=16, PA=25, Backlinks=311
#     ✅ allforthefamilylegalclinic.org: DA=18, PA=28, Backlinks=202
#     ✅ vsfamlaw.com: DA=22, PA=30, Backlinks=3,719
#     ✅ ca.gov: DA=93, PA=62, Backlinks=329,462,764
#     ✅ csyfamilylaw.com: DA=20, PA=23, Backlinks=341
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 12/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ drsfamilylaw.com: DA=19, PA=25, Backlinks=942
#     ✅ collaborativedivorcegoldengate.org: DA=17, PA=22, Backlinks=3,035
#     ✅ arlenekostantlaw.com: DA=11, PA=19, Backlinks=194
#     ✅ kslmpractice.com: DA=14, PA=22, Backlinks=504
#     ✅ sandiegofamilylawyer.net: DA=29, PA=37, Backlinks=3,797
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 13/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ duanemorris.com: DA=56, PA=50, Backlinks=444,232
#     ✅ jmbm.com: DA=48, PA=49, Backlinks=229,570
#     ✅ bankruptcypower.com: DA=29, PA=32, Backlinks=9,163
#     ✅ compassbankruptcy.com: DA=11, PA=19, Backlinks=55
#     ✅ thebankruptcylawfirm.net: DA=22, PA=26, Backlinks=812
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 14/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ phillaw.com: DA=25, PA=31, Backlinks=834
#     ✅ wsgr.com: DA=56, PA=51, Backlinks=320,036
#     ✅ akingump.com: DA=59, PA=51, Backlinks=271,076
#     ✅ helbraunlaw.com: DA=17, PA=32, Backlinks=8,357
#     ✅ moskowitzllp.com: DA=37, PA=41, Backlinks=9,771
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 15/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ andrewljones.com: DA=19, PA=28, Backlinks=838
#     ✅ expatriationattorneys.com: DA=19, PA=39, Backlinks=1,972
#     ✅ taxhelpers.com: DA=30, PA=36, Backlinks=4,098
#     ✅ ca.gov: DA=93, PA=63, Backlinks=329,462,764
#     ✅ regaltaxlaw.com: DA=18, PA=26, Backlinks=1,520
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 16/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ uclawsf.edu: DA=65, PA=42, Backlinks=24,911,774
#     ✅ dergnoah.com: DA=28, PA=30, Backlinks=867
#     ✅ kingkelleher.com: DA=15, PA=24, Backlinks=132
#     ✅ kr.law: DA=19, PA=37, Backlinks=9,676
#     ✅ knobbe.com: DA=44, PA=45, Backlinks=53,421
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 17/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ kugelmanlaw.com: DA=16, PA=36, Backlinks=1,810
#     ✅ sanfranciscoimmigrationlaw.com: DA=22, PA=31, Backlinks=1,253
#     ✅ lpimmigration.com: DA=19, PA=21, Backlinks=1,074
#     ✅ brownimmigrationlaw.com: DA=27, PA=32, Backlinks=929
#     ✅ fragomen.com: DA=55, PA=51, Backlinks=106,960
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 18/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ arajlaw.com: DA=20, PA=31, Backlinks=829
#     ✅ sidley.com: DA=60, PA=51, Backlinks=300,378
#     ✅ sflaw.com: DA=29, PA=35, Backlinks=54,439
#     ✅ kazlg.com: DA=31, PA=40, Backlinks=4,833
#     ✅ walkuplawoffice.com: DA=40, PA=41, Backlinks=20,531
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 19/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ccwlawyers.com: DA=25, PA=33, Backlinks=3,102
#     ✅ dgglaw.com: DA=27, PA=33, Backlinks=1,676
#     ✅ sallymorinlaw.com: DA=31, PA=41, Backlinks=7,133
#     ✅ hershlaw.com: DA=25, PA=32, Backlinks=1,756
#     ✅ callawayandwolf.com: DA=30, PA=34, Backlinks=3,019
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 20/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ legalmetro.com: DA=23, PA=32, Backlinks=2,083
#     ✅ zinn-law.com: DA=20, PA=26, Backlinks=7,159
#     ✅ smwlaw.com: DA=36, PA=31, Backlinks=1,718
#     ✅ cpmlegal.com: DA=53, PA=45, Backlinks=21,463
#     ✅ eghblaw.com: DA=26, PA=24, Backlinks=29,153
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 21/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ huschblackwell.com: DA=52, PA=50, Backlinks=306,938
#     ✅ ca.gov: DA=93, PA=61, Backlinks=329,462,764
#     ✅ bamlawca.com: DA=37, PA=38, Backlinks=5,020
#     ✅ pasternaklaw.com: DA=29, PA=36, Backlinks=1,536
#     ✅ bmcclaw.com: DA=18, PA=31, Backlinks=1,016
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 22/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ josephwaxman.com: DA=10, PA=18, Backlinks=307
#     ✅ jvlaw.com: DA=17, PA=33, Backlinks=2,483
#     ✅ leclerclaw.com: DA=19, PA=26, Backlinks=2,334
#     ✅ bryanschwartzlaw.com: DA=25, PA=35, Backlinks=4,586
#     ✅ sugarmanandcannon.com: DA=18, PA=28, Backlinks=1,329
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 23/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ constantinecannon.com: DA=51, PA=45, Backlinks=13,444
#     ✅ phillipsandcohen.com: DA=49, PA=41, Backlinks=17,224
#     ✅ evanslaw.com: DA=31, PA=33, Backlinks=6,143
#     ✅ sftaxappeal.com: DA=15, PA=21, Backlinks=49
#     ✅ halversontax.com: DA=14, PA=31, Backlinks=1,484
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 24/25: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ cirruslawpc.com: DA=18, PA=26, Backlinks=5,307
#     ✅ kingsiegel.com: DA=29, PA=35, Backlinks=2,753
#     ✅ fedemploymentlaw.com: DA=31, PA=33, Backlinks=1,212,861
#     ✅ pinesfederal.com: DA=28, PA=36, Backlinks=6,913
#     ✅ sampathlaw.com: DA=10, PA=27, Backlinks=203
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 25/25: 6 URLs
#     🔍 Requesting Moz data for 6 URLs...
#     📊 Response status: 200
#     ✅ Got data for 6 URLs
#     ✅ samndan.com: DA=28, PA=40, Backlinks=6,267
#     ✅ maternlawgroup.com: DA=27, PA=32, Backlinks=868
#     ✅ egcounsel.com: DA=11, PA=28, Backlinks=194
#     ✅ cartwrightlaw.com: DA=25, PA=37, Backlinks=4,748
#     ✅ robertkinglawfirm.com: DA=35, PA=38, Backlinks=7,464
#     ... and 1 more domains
#
# 📋 Applying Moz results to dataframe...
#
# 📊 TOP3 Results Summary:
# 💾 Saved: San_Francisco_top3_moz_enriched.csv
# 📈 Enriched rows: 1,602/1,633
# 🏆 Max Domain Authority: 93
# 📊 Avg Domain Authority: 32.4
# 🔗 Max Backlinks: 4,669,729,396
# 📊 Total Backlinks: 28,891,537,792
# 💰 Actual cost: ~$2.46
#
# 💤 Waiting 5 seconds before TOP10...
#
# 🚀 Starting TOP10 enrichment...
#
# 🌉 Processing San Francisco TOP10 - COMPLETE VERSION
# ================================================================================
# 📄 Loaded 5877 rows from top10
# 🌐 Found 656 unique domains
# 💰 Estimated cost: $6.56
# ⏱️ Estimated time: 2.2 minutes
# 🔝 Sample domains: ['tslo.com', 'eastbaybusinesslawyer.com', 'zfplaw.com', 'lccrsf.org', 'shaperolawfirm.com']
#   📊 Moz enrichment for 656 domains in San Francisco top10
#   🎯 Processing 656 URLs in batches of 10
#
#   📦 Batch 1/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ tslo.com: DA=25, PA=25, Backlinks=5,275
#     ✅ eastbaybusinesslawyer.com: DA=12, PA=24, Backlinks=177
#     ✅ zfplaw.com: DA=27, PA=32, Backlinks=3,591
#     ✅ lccrsf.org: DA=44, PA=41, Backlinks=2,665
#     ✅ shaperolawfirm.com: DA=17, PA=23, Backlinks=99
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 2/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ severson.com: DA=33, PA=35, Backlinks=2,907
#     ✅ woodlitigation.com: DA=19, PA=28, Backlinks=359
#     ✅ hklaw.com: DA=61, PA=53, Backlinks=688,888
#     ✅ gibsondunn.com: DA=61, PA=52, Backlinks=291,191
#     ✅ strategylaw.com: DA=21, PA=33, Backlinks=1,915
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 3/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ prattattorneys.com: DA=26, PA=30, Backlinks=1,470
#     ✅ davis-stirling.com: DA=41, PA=46, Backlinks=90,680
#     ✅ shjeflo-riley-cruz-llp.com: DA=14, PA=18, Backlinks=24
#     ✅ lawforhoas.com: DA=28, PA=30, Backlinks=10,346
#     ✅ tinnellylaw.com: DA=34, PA=37, Backlinks=5,449
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 4/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ssllawfirm.com: DA=25, PA=29, Backlinks=892
#     ✅ mcwrealestatelaw.com: DA=16, PA=34, Backlinks=691
#     ✅ reubenlaw.com: DA=33, PA=37, Backlinks=75,096
#     ✅ vonrocklaw.com: DA=10, PA=39, Backlinks=690
#     ✅ sheppardlaw.com: DA=21, PA=28, Backlinks=3,088
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 5/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ rbgg.com: DA=45, PA=39, Backlinks=3,993
#     ✅ ayannajenkinstoney.com: DA=24, PA=26, Backlinks=1,152
#     ✅ lpslaw.com: DA=26, PA=30, Backlinks=981
#     ✅ roboostoff-kalkin.com: DA=19, PA=31, Backlinks=4,308
#     ✅ bayarea-attorney.com: DA=32, PA=37, Backlinks=3,217
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 6/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ogletree.com: DA=55, PA=54, Backlinks=519,116
#     ✅ axiomlaw.com: DA=46, PA=48, Backlinks=55,077
#     ✅ jonesday.com: DA=62, PA=53, Backlinks=354,385
#     ✅ cov.com: DA=60, PA=51, Backlinks=114,809
#     ✅ willkie.com: DA=51, PA=48, Backlinks=40,348
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 7/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ crownllp.com: DA=15, PA=25, Backlinks=178
#     ✅ filmtvlaw.com: DA=31, PA=32, Backlinks=125,990
#     ✅ mpbf.com: DA=30, PA=34, Backlinks=1,127
#     ✅ idellfirm.com: DA=15, PA=26, Backlinks=4,261
#     ✅ risselllawfirm.com: DA=4, PA=19, Backlinks=23
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 8/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ donahue.com: DA=37, PA=38, Backlinks=6,259
#     ✅ legalzoom.com: DA=68, PA=50, Backlinks=1,074,208
#     ✅ thehollywoodlawyer.com: DA=31, PA=38, Backlinks=1,686
#     ✅ calawyersforthearts.org: DA=44, PA=41, Backlinks=19,944
#     ✅ opendoorlegal.org: DA=29, PA=35, Backlinks=846
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 9/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ lrcl.org: DA=32, PA=35, Backlinks=2,297
#     ✅ ca.gov: DA=93, PA=64, Backlinks=329,462,764
#     ✅ coxcastle.com: DA=42, PA=38, Backlinks=17,752
#     ✅ eghblaw.com: DA=26, PA=24, Backlinks=29,153
#     ✅ alvesradcliffe.com: DA=20, PA=25, Backlinks=553
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 10/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ smithbaltaxe.com: DA=21, PA=28, Backlinks=483
#     ✅ thematiasicfirm.com: DA=20, PA=28, Backlinks=4,226
#     ✅ brodfirm.com: DA=22, PA=31, Backlinks=56,670
#     ✅ samndan.com: DA=28, PA=40, Backlinks=6,267
#     ✅ bostwickfirm.com: DA=29, PA=34, Backlinks=5,591
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 11/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ mballenlaw.com: DA=19, PA=26, Backlinks=1,270
#     ✅ joclaw.com: DA=27, PA=31, Backlinks=1,487
#     ✅ berding-weil.com: DA=36, PA=36, Backlinks=5,730
#     ✅ yaronlaw.com: DA=21, PA=25, Backlinks=423
#     ✅ arnslaw.com: DA=27, PA=33, Backlinks=1,116
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 12/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ dpllp.com: DA=17, PA=30, Backlinks=1,827
#     ✅ bowlesverna.com: DA=26, PA=35, Backlinks=3,589
#     ✅ ponlaw.com: DA=19, PA=32, Backlinks=1,693
#     ✅ valerynechaylaw.com: DA=22, PA=39, Backlinks=2,624
#     ✅ sanfranciscoduidefense.com: DA=16, PA=26, Backlinks=740
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 13/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ burglin.com: DA=19, PA=30, Backlinks=5,797
#     ✅ bortelduidefense.com: DA=23, PA=30, Backlinks=1,172
#     ✅ bayareaduidefense.com: DA=17, PA=32, Backlinks=2,208
#     ✅ gellerlawsf.com: DA=21, PA=32, Backlinks=400
#     ✅ uthmanlawoffice.com: DA=10, PA=27, Backlinks=5,937
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 14/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ kazarianatlaw.com: DA=28, PA=34, Backlinks=1,648
#     ✅ dui1guy.com: DA=23, PA=32, Backlinks=1,464
#     ✅ sfcdui.com: DA=7, PA=19, Backlinks=181
#     ✅ attorneys.media: DA=39, PA=40, Backlinks=10,729
#     ✅ quora.com: DA=93, PA=75, Backlinks=128,324,681
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 15/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ mattsullivanlaw.com: DA=19, PA=27, Backlinks=2,070
#     ✅ jagrooplaw.com: DA=23, PA=30, Backlinks=960
#     ✅ walravenlawoffices.com: DA=12, PA=25, Backlinks=337
#     ✅ walialawfirm.com: DA=29, PA=36, Backlinks=5,111
#     ✅ sanfranciscodui.com: DA=12, PA=23, Backlinks=179
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 16/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ patfordappeals.com: DA=15, PA=27, Backlinks=3,019
#     ✅ os-legal.com: DA=17, PA=32, Backlinks=4,398
#     ✅ spolinlaw.com: DA=32, PA=38, Backlinks=18,085
#     ✅ beleslaw.com: DA=31, PA=37, Backlinks=3,576
#     ✅ esilverlaw.com: DA=33, PA=33, Backlinks=4,789
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 17/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ klasing-associates.com: DA=42, PA=45, Backlinks=13,705
#     ✅ thebulldog.law: DA=24, PA=42, Backlinks=17,206
#     ✅ danielbakondi.com: DA=22, PA=25, Backlinks=3,901
#     ✅ personalinjurylawcal.com: DA=36, PA=46, Backlinks=29,220
#     ✅ lowelaw.com: DA=24, PA=36, Backlinks=2,953
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 18/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ gilfix.com: DA=27, PA=32, Backlinks=5,923
#     ✅ kfslaw.net: DA=18, PA=25, Backlinks=61
#     ✅ yourmusiclawyer.com: DA=12, PA=19, Backlinks=36
#     ✅ nonprofitlegalcenter.com: DA=21, PA=38, Backlinks=5,758
#     ✅ californianonprofitlaw.com: DA=8, PA=22, Backlinks=150
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 19/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ca.gov: DA=93, PA=62, Backlinks=329,462,764
#     ✅ cpt.law: DA=23, PA=37, Backlinks=7,916
#     ✅ oneil.legal: DA=10, PA=22, Backlinks=584
#     ✅ mysfers.org: DA=35, PA=42, Backlinks=31,377
#     ✅ sclawlib.org: DA=22, PA=36, Backlinks=838
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 20/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ connieyilaw.com: DA=22, PA=30, Backlinks=4,569
#     ✅ defontelaw.com: DA=22, PA=26, Backlinks=278
#     ✅ ca.gov: DA=93, PA=61, Backlinks=329,462,764
#     ✅ dcrawfordlaw.com: DA=11, PA=27, Backlinks=108
#     ✅ talbotlawpc.com: DA=22, PA=24, Backlinks=3,590
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 21/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sgg-lawfirm.com: DA=26, PA=18, Backlinks=39,246
#     ✅ tswrobel.law: DA=13, PA=26, Backlinks=432
#     ✅ probateattorneysanfrancisco.com: DA=13, PA=24, Backlinks=197
#     ✅ shamiehlawsf.com: DA=16, PA=30, Backlinks=304
#     ✅ immigrate-us.net: DA=17, PA=31, Backlinks=3,158
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 22/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ fragomen.com: DA=55, PA=51, Backlinks=106,960
#     ✅ sf.gov: DA=74, PA=40, Backlinks=1,963,984
#     ✅ carecensf.org: DA=36, PA=39, Backlinks=2,129
#     ✅ icwclaw.org: DA=38, PA=40, Backlinks=1,951
#     ✅ immigrationadvocates.org: DA=55, PA=47, Backlinks=45,586
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 23/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sfimmigrationlawyer.com: DA=11, PA=21, Backlinks=91
#     ✅ lpimmigration.com: DA=19, PA=21, Backlinks=1,074
#     ✅ sackettlaw.com: DA=22, PA=32, Backlinks=1,772
#     ✅ robertsdisability.com: DA=18, PA=33, Backlinks=1,771
#     ✅ laportelawfirm.com: DA=33, PA=36, Backlinks=2,248
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 24/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ andalmanflynn.com: DA=32, PA=39, Backlinks=5,189
#     ✅ leighlawgroup.com: DA=25, PA=34, Backlinks=2,733
#     ✅ federaldisability.com: DA=28, PA=38, Backlinks=8,899
#     ✅ prcsf.org: DA=40, PA=41, Backlinks=6,694
#     ✅ hawkinscenter.org: DA=13, PA=23, Backlinks=198
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 25/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ ca.gov: DA=93, PA=62, Backlinks=329,462,764
#     ✅ herrenlaw.com: DA=24, PA=32, Backlinks=2,346
#     ✅ woodslawyers.com: DA=32, PA=44, Backlinks=23,142
#     ✅ atticus.com: DA=39, PA=43, Backlinks=7,993
#     ✅ yelp.com: DA=93, PA=67, Backlinks=399,458,634
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 26/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ dobrovlaw.com: DA=18, PA=25, Backlinks=280
#     ✅ baylegal.com: DA=14, PA=26, Backlinks=2,192
#     ✅ infinitylawca.com: DA=14, PA=25, Backlinks=2,620
#     ✅ loewlawgroup.com: DA=26, PA=35, Backlinks=2,515
#     ✅ blacksburg-law.com: DA=19, PA=30, Backlinks=673
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 27/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ bayarea-criminaldefense.com: DA=23, PA=29, Backlinks=2,905
#     ✅ thenieveslawfirm.com: DA=33, PA=41, Backlinks=5,341
#     ✅ bayareacrimlaw.com: DA=25, PA=31, Backlinks=732
#     ✅ summitdefense.com: DA=33, PA=38, Backlinks=15,194
#     ✅ sfcriminallawspecialist.com: DA=34, PA=37, Backlinks=4,348
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 28/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ record-clear.com: DA=19, PA=32, Backlinks=1,068
#     ✅ federal-lawyer.com: DA=40, PA=49, Backlinks=24,594
#     ✅ dickinson-wright.com: DA=49, PA=47, Backlinks=76,847
#     ✅ quinnemanuel.com: DA=56, PA=48, Backlinks=53,098
#     ✅ buchalter.com: DA=45, PA=43, Backlinks=89,332
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 29/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ perkinscoie.com: DA=59, PA=54, Backlinks=371,485
#     ✅ pattersononeill.com: DA=9, PA=19, Backlinks=46
#     ✅ goodelllawsf.com: DA=5, PA=23, Backlinks=107
#     ✅ sparerlaw.com: DA=20, PA=24, Backlinks=8,166
#     ✅ g3mh.com: DA=21, PA=35, Backlinks=855
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 30/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ edgarfamilylaw.com: DA=28, PA=37, Backlinks=5,908
#     ✅ dwdignity.com: DA=31, PA=38, Backlinks=1,254
#     ✅ csyfamilylaw.com: DA=20, PA=23, Backlinks=341
#     ✅ thegillfirm.com: DA=23, PA=30, Backlinks=1,350
#     ✅ californiafamilylawgroup.com: DA=28, PA=30, Backlinks=10,087
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 31/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sfgov.org: DA=69, PA=60, Backlinks=3,262,835
#     ✅ sfusd.edu: DA=60, PA=53, Backlinks=1,080,275
#     ✅ gellerfirm.com: DA=17, PA=27, Backlinks=563
#     ✅ nclwlaw.com: DA=16, PA=21, Backlinks=202
#     ✅ seeleyfamilylaw.com: DA=23, PA=30, Backlinks=4,347
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 32/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ civilrightsbayarea.com: DA=19, PA=19, Backlinks=455
#     ✅ collaborativedivorcecalifornia.com: DA=18, PA=34, Backlinks=4,776
#     ✅ bayareamediationandcollaborativedivorce.com: DA=5, PA=21, Backlinks=37
#     ✅ elterlawoffices.com: DA=15, PA=22, Backlinks=87
#     ✅ chaseberensteinandmurray.com: DA=21, PA=27, Backlinks=995
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 33/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ bayareaelderlaw.com: DA=26, PA=32, Backlinks=2,149
#     ✅ psychologytoday.com: DA=93, PA=71, Backlinks=25,243,941
#     ✅ nih.gov: DA=95, PA=81, Backlinks=3,239,942,002
#     ✅ farzadlaw.com: DA=39, PA=47, Backlinks=21,414
#     ✅ onemomsbattle.com: DA=39, PA=40, Backlinks=10,470
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 34/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ eastbaylevinelaw.com: DA=32, PA=40, Backlinks=3,733
#     ✅ parentalrightsdefenders.com: DA=10, PA=21, Backlinks=53
#     ✅ cyruspacificlaw.com: DA=28, PA=22, Backlinks=104
#     ✅ acbanet.org: DA=41, PA=39, Backlinks=7,445
#     ✅ smhlawmed.net: DA=17, PA=27, Backlinks=540
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 35/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ bayareabk.com: DA=22, PA=29, Backlinks=468
#     ✅ sfbay-law.com: DA=22, PA=29, Backlinks=551
#     ✅ resolvelawfirm.com: DA=20, PA=29, Backlinks=142
#     ✅ thebankruptcylawfirm.net: DA=22, PA=26, Backlinks=812
#     ✅ bklegalaid.com: DA=10, PA=19, Backlinks=142
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 36/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ compassbankruptcy.com: DA=11, PA=19, Backlinks=55
#     ✅ pszjlaw.com: DA=33, PA=41, Backlinks=46,813
#     ✅ mccarthylawyer.com: DA=32, PA=41, Backlinks=7,089
#     ✅ bwlawcenter.com: DA=19, PA=24, Backlinks=380
#     ✅ jdl.law: DA=16, PA=29, Backlinks=2,585
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 37/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sfcityattorney.org: DA=58, PA=44, Backlinks=21,719
#     ✅ geonetta-frucht.com: DA=18, PA=31, Backlinks=652
#     ✅ delawllp.com: DA=21, PA=23, Backlinks=2,133
#     ✅ coepiolegal.com: DA=12, PA=28, Backlinks=3,829
#     ✅ blgrp.com: DA=7, PA=23, Backlinks=176
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 38/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ nka.com: DA=39, PA=36, Backlinks=6,873
#     ✅ svtechlaws.com: DA=17, PA=24, Backlinks=583
#     ✅ orrick.com: DA=68, PA=52, Backlinks=1,041,802
#     ✅ moskowitzllp.com: DA=37, PA=41, Backlinks=9,771
#     ✅ jdteterlaw.com: DA=19, PA=30, Backlinks=1,576
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 39/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ andersen.com: DA=56, PA=51, Backlinks=673,431
#     ✅ safeharborcpa.com: DA=24, PA=33, Backlinks=2,358
#     ✅ feeonlynetwork.com: DA=39, PA=40, Backlinks=135,101
#     ✅ morlingfinancialadvisors.com: DA=15, PA=28, Backlinks=276
#     ✅ tonyquach.com: DA=11, PA=25, Backlinks=127
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 40/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ dimovtax.com: DA=27, PA=42, Backlinks=3,096
#     ✅ kbfinancialadvisors.com: DA=26, PA=42, Backlinks=3,769
#     ✅ bark.com: DA=73, PA=58, Backlinks=3,696,181
#     ✅ andrewljones.com: DA=19, PA=28, Backlinks=838
#     ✅ expatriationattorneys.com: DA=19, PA=39, Backlinks=1,972
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 41/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ irs.gov: DA=91, PA=75, Backlinks=56,084,602
#     ✅ collective.com: DA=49, PA=49, Backlinks=42,040
#     ✅ sftreasurer.org: DA=54, PA=49, Backlinks=58,453
#     ✅ incorporatecalifornia.com: DA=22, PA=35, Backlinks=3,882
#     ✅ hrblock.com: DA=71, PA=60, Backlinks=2,024,524
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 42/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ kjmlaw.com: DA=23, PA=30, Backlinks=652
#     ✅ gtlaw.com: DA=59, PA=53, Backlinks=569,210
#     ✅ twsglaw.com: DA=17, PA=27, Backlinks=2,363
#     ✅ sftaxappeal.com: DA=15, PA=21, Backlinks=49
#     ✅ usfca.edu: DA=78, PA=57, Backlinks=1,356,894
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 43/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ boldip.com: DA=37, PA=44, Backlinks=57,832
#     ✅ kingkelleher.com: DA=15, PA=24, Backlinks=132
#     ✅ kr.law: DA=19, PA=37, Backlinks=9,676
#     ✅ dhillonlaw.com: DA=51, PA=41, Backlinks=10,944
#     ✅ cerallp.com: DA=17, PA=24, Backlinks=255
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 44/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ goodwinlaw.com: DA=55, PA=49, Backlinks=209,385
#     ✅ desmaraisllp.com: DA=25, PA=31, Backlinks=1,110
#     ✅ fr.com: DA=63, PA=50, Backlinks=133,874
#     ✅ saverilawfirm.com: DA=40, PA=38, Backlinks=7,413
#     ✅ ktslaw.com: DA=49, PA=36, Backlinks=830,900
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 45/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ peillaw.com: DA=13, PA=28, Backlinks=3,345
#     ✅ adibiip.com: DA=20, PA=31, Backlinks=662
#     ✅ bayoaklaw.com: DA=26, PA=28, Backlinks=2,668
#     ✅ clfip.com: DA=24, PA=32, Backlinks=6,469
#     ✅ cognitionip.com: DA=24, PA=34, Backlinks=811
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 46/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ wilmerhale.com: DA=69, PA=50, Backlinks=334,086
#     ✅ manatt.com: DA=58, PA=50, Backlinks=355,434
#     ✅ kkc.com: DA=48, PA=43, Backlinks=12,076
#     ✅ dilendorf.com: DA=29, PA=40, Backlinks=22,108
#     ✅ vondranlegal.com: DA=36, PA=40, Backlinks=22,458
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 47/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ reevesimmigration.com: DA=20, PA=32, Backlinks=1,116
#     ✅ nasirilaw.com: DA=24, PA=28, Backlinks=1,755
#     ✅ smcgov.org: DA=60, PA=49, Backlinks=666,443
#     ✅ jubileelegal.org: DA=21, PA=30, Backlinks=432
#     ✅ santaclaracounty.gov: DA=67, PA=27, Backlinks=735,031
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 48/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ harrisonimmigration.com: DA=14, PA=23, Backlinks=136
#     ✅ hafeykarim.com: DA=17, PA=19, Backlinks=1,312
#     ✅ hirayaimmigration.com: DA=9, PA=19, Backlinks=459
#     ✅ wileyjobson.com: DA=21, PA=25, Backlinks=790
#     ✅ warrenlawfirm.net: DA=27, PA=37, Backlinks=2,246
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 49/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ centrolegal.org: DA=48, PA=42, Backlinks=9,571
#     ✅ troylaw.net: DA=24, PA=28, Backlinks=1,025
#     ✅ schneiderwallace.com: DA=36, PA=36, Backlinks=58,459
#     ✅ pmrklaw.com: DA=12, PA=26, Backlinks=1,104
#     ✅ tong-law.com: DA=25, PA=31, Backlinks=3,942
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 50/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ lieffcabraser.com: DA=60, PA=45, Backlinks=26,808
#     ✅ sidley.com: DA=60, PA=51, Backlinks=300,378
#     ✅ paulhastings.com: DA=58, PA=50, Backlinks=482,859
#     ✅ mofo.com: DA=62, PA=52, Backlinks=298,243
#     ✅ gunder.com: DA=42, PA=44, Backlinks=15,277
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 51/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ kevinsullivanlegal.com: DA=11, PA=22, Backlinks=422
#     ✅ westcoastbk.com: DA=22, PA=31, Backlinks=2,746
#     ✅ macleanchung.com: DA=22, PA=30, Backlinks=1,677
#     ✅ uscourts.gov: DA=84, PA=56, Backlinks=402,145,528
#     ✅ walkuplawoffice.com: DA=40, PA=41, Backlinks=20,531
#     ... and 4 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 52/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sallymorinlaw.com: DA=31, PA=41, Backlinks=7,133
#     ✅ sfbike.org: DA=61, PA=51, Backlinks=324,291
#     ✅ bayareabicyclelaw.com: DA=32, PA=39, Backlinks=4,847
#     ✅ zinn-law.com: DA=20, PA=26, Backlinks=7,159
#     ✅ coopers.law: DA=13, PA=22, Backlinks=276
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 53/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ dgglaw.com: DA=27, PA=33, Backlinks=1,676
#     ✅ russbrown.com: DA=39, PA=46, Backlinks=211,807
#     ✅ kermanillp.com: DA=27, PA=30, Backlinks=3,282
#     ✅ williamweisslaw.com: DA=18, PA=31, Backlinks=4,581
#     ✅ sweetjames.com: DA=30, PA=45, Backlinks=165,511
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 54/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ wisnerbaum.com: DA=57, PA=37, Backlinks=78,408
#     ✅ wilshirelawfirm.com: DA=36, PA=46, Backlinks=14,955
#     ✅ panish.law: DA=50, PA=29, Backlinks=75,071
#     ✅ bencrump.com: DA=51, PA=53, Backlinks=43,119
#     ✅ buzzlaw.com: DA=17, PA=27, Backlinks=1,070
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 55/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ skg-law.com: DA=17, PA=25, Backlinks=87
#     ✅ gjel.com: DA=46, PA=46, Backlinks=34,297
#     ✅ smwlaw.com: DA=36, PA=31, Backlinks=1,718
#     ✅ sheredling.com: DA=42, PA=30, Backlinks=1,940
#     ✅ bdlaw.com: DA=46, PA=46, Backlinks=86,179
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 56/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ bakerbotts.com: DA=53, PA=49, Backlinks=378,137
#     ✅ earthjustice.org: DA=71, PA=62, Backlinks=1,476,257
#     ✅ cwlfirm.com: DA=22, PA=33, Backlinks=2,180
#     ✅ briscoelaw.net: DA=24, PA=34, Backlinks=583
#     ✅ greenfirelaw.com: DA=16, PA=27, Backlinks=180
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 57/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ goldbergsegalla.com: DA=46, PA=42, Backlinks=266,303
#     ✅ kslaw.com: DA=59, PA=50, Backlinks=173,868
#     ✅ ca.gov: DA=93, PA=61, Backlinks=329,462,764
#     ✅ kmtg.com: DA=36, PA=37, Backlinks=162,835
#     ✅ bamlawca.com: DA=37, PA=38, Backlinks=5,020
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 58/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ littler.com: DA=64, PA=52, Backlinks=915,626
#     ✅ jvlaw.com: DA=17, PA=33, Backlinks=2,483
#     ✅ alancohenlaw.com: DA=7, PA=25, Backlinks=226
#     ✅ jobdiscrimination.org: DA=19, PA=38, Backlinks=2,961
#     ✅ sanfordheisler.com: DA=50, PA=44, Backlinks=96,443
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 59/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ leclerclaw.com: DA=19, PA=26, Backlinks=2,334
#     ✅ josephwaxman.com: DA=10, PA=18, Backlinks=307
#     ✅ workplacelegalpc.com: DA=17, PA=33, Backlinks=575
#     ✅ thearmstronglawfirm.com: DA=25, PA=36, Backlinks=5,573
#     ✅ sampathlaw.com: DA=10, PA=27, Backlinks=203
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 60/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ tiemannlawfirm.com: DA=24, PA=42, Backlinks=7,150
#     ✅ halversontax.com: DA=14, PA=31, Backlinks=1,484
#     ✅ faegredrinker.com: DA=56, PA=46, Backlinks=891,658
#     ✅ salestaxhelp.com: DA=26, PA=35, Backlinks=2,947
#     ✅ salestaxhelper.com: DA=22, PA=41, Backlinks=2,568
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 61/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ bayareafamilylawcenter.com: DA=17, PA=26, Backlinks=4,318
#     ✅ cartwrightlaw.com: DA=25, PA=37, Backlinks=4,748
#     ✅ allegiancelaw.com: DA=25, PA=34, Backlinks=4,239
#     ✅ bridges-law-firm.com: DA=20, PA=29, Backlinks=230
#     ✅ haffnerlawyers.com: DA=29, PA=37, Backlinks=5,850
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 62/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ levelset.com: DA=46, PA=51, Backlinks=1,189,848
#     ✅ ottingerlaw.com: DA=35, PA=42, Backlinks=8,547
#     ✅ avlonilaw.com: DA=20, PA=31, Backlinks=327
#     ✅ blackstonepc.com: DA=24, PA=38, Backlinks=1,453
#     ✅ fedemploymentlaw.com: DA=31, PA=33, Backlinks=1,212,861
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 63/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ swansonmcnamara.com: DA=23, PA=28, Backlinks=321
#     ✅ sfpublicdefender.org: DA=47, PA=45, Backlinks=4,729
#     ✅ ndcalfpd.org: DA=29, PA=30, Backlinks=1,917
#     ✅ therosenfeldlawfirm.com: DA=20, PA=30, Backlinks=1,272
#     ✅ rspollocklaw.com: DA=29, PA=26, Backlinks=996
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 64/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ sanfranciscobestcriminallawyer.com: DA=13, PA=21, Backlinks=262
#     ✅ greenbergrubylaw.com: DA=29, PA=32, Backlinks=1,521
#     ✅ californiabirthinjurylawfirm.com: DA=9, PA=25, Backlinks=203
#     ✅ mitchell-leeds.com: DA=12, PA=21, Backlinks=3,804
#     ✅ ca.gov: DA=93, PA=61, Backlinks=329,462,764
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 65/66: 10 URLs
#     🔍 Requesting Moz data for 10 URLs...
#     📊 Response status: 200
#     ✅ Got data for 10 URLs
#     ✅ kornblumlaw.com: DA=19, PA=31, Backlinks=5,269
#     ✅ lessergroup.com: DA=18, PA=26, Backlinks=1,631
#     ✅ righthandfirm.com: DA=24, PA=31, Backlinks=3,789
#     ✅ ggu.edu: DA=61, PA=52, Backlinks=1,028,229
#     ✅ hunton.com: DA=59, PA=48, Backlinks=691,566
#     ... and 5 more domains
#     💤 Waiting 2 seconds...
#
#   📦 Batch 66/66: 6 URLs
#     🔍 Requesting Moz data for 6 URLs...
#     📊 Response status: 200
#     ✅ Got data for 6 URLs
#     ✅ bargcoffin.com: DA=24, PA=25, Backlinks=2,852
#     ✅ levylaw.com: DA=39, PA=38, Backlinks=26,701
#     ✅ robertkinglawfirm.com: DA=35, PA=38, Backlinks=7,464
#     ✅ watercontaminationlawsuits.com: DA=16, PA=30, Backlinks=640
#     ✅ pbp.law: DA=4, PA=16, Backlinks=23
#     ... and 1 more domains
#
# 📋 Applying Moz results to dataframe...
#
# 📊 TOP10 Results Summary:
# 💾 Saved: San_Francisco_top10_moz_enriched.csv
# 📈 Enriched rows: 5,790/5,877
# 🏆 Max Domain Authority: 93
# 📊 Avg Domain Authority: 31.9
# 🔗 Max Backlinks: 4,669,729,396
# 📊 Total Backlinks: 350,496,905,191
# 💰 Actual cost: ~$6.56
#
# 🎉 San Francisco Complete Enrichment Finished!
# ====================================================================================================
# ✅ TOP3: 1,633 rows, 239 domains
#    Max DA: 93, Total Backlinks: 28,891,537,792
# ✅ TOP10: 5,877 rows, 644 domains
#    Max DA: 93, Total Backlinks: 350,496,905,191
#
# 📊 Final Statistics:
# 🌐 Total unique domains processed: 883
# 💰 Total cost: ~$8.83
# 📂 Output files saved to: /content/drive/MyDrive/Part 2/Moz_Enriched_Results
# 📄 Generated files:
#   - San_Francisco_top3_moz_enriched.csv
#   - San_Francisco_top10_moz_enriched.csv
#
# 🏆 Top Performing Domains Analysis:
# 🥇 Top 5 by Domain Authority:
#   1. nih.gov: DA=95, PA=81, Backlinks=3,239,942,002
#   2. ca.gov: DA=93, PA=61, Backlinks=329,462,764
#   3. sfgate.com: DA=93, PA=71, Backlinks=41,445,886
#   4. quora.com: DA=93, PA=75, Backlinks=128,324,681
#   5. yelp.com: DA=93, PA=67, Backlinks=399,458,634
#
# ✨ San Francisco enrichment completed successfully!
# 🎯 Ready for analysis with complete Domain Authority and Page Authority data!

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import pandas as pd
import requests
import base64
import time
import json
import glob
from urllib.parse import urlparse
from datetime import datetime, timezone

# === Moz API 认证信息 ===
MOZ_ACCESS_ID = "mozscape-pn863y8erR"
MOZ_SECRET_KEY = "CpBLhVJlFaCEe9EPQkOoLjO6UF0iKUUf"

# === 路径设置 ===
BASE_PATH = "/content/drive/MyDrive/Part 1"
OUTPUT_BASE_PATH = "/content/drive/MyDrive/Part 1/Moz_Enriched_Results"
PROGRESS_FILE = "/content/drive/MyDrive/Part 1/Moz_Enriched_Results/processing_progress.json"

# 创建输出目录
os.makedirs(OUTPUT_BASE_PATH, exist_ok=True)

def extract_domain(url):
    """提取域名"""
    try:
        return urlparse(url).netloc.replace("www.", "")
    except:
        return None

def safe_join_backlinks(domain, moz_results):
    """安全地连接backlinks数据"""
    try:
        backlinks = moz_results.get(domain, {}).get("top_backlinks", [])
        if not backlinks:
            return ""

        str_backlinks = []
        for link in backlinks:
            if isinstance(link, str):
                str_backlinks.append(link)
            elif isinstance(link, dict):
                url = link.get('source', '') or link.get('url', '') or str(link)
                str_backlinks.append(url)
            else:
                str_backlinks.append(str(link))

        return "; ".join(str_backlinks)
    except Exception as e:
        print(f"    ⚠️ Error processing backlinks for {domain}: {e}")
        return ""

def get_moz_url_metrics(urls_batch):
    """获取Moz URL指标"""
    endpoint = "https://lsapi.seomoz.com/v2/url_metrics"

    headers = {
        "Authorization": f"Basic {base64.b64encode(f'{MOZ_ACCESS_ID}:{MOZ_SECRET_KEY}'.encode()).decode()}",
        "Content-Type": "application/json"
    }

    payload = {"targets": urls_batch}

    try:
        response = requests.post(endpoint, headers=headers, json=payload)

        if response.status_code == 200:
            data = response.json()
            return data.get('results', [])
        else:
            print(f"    ❌ Error: {response.status_code} - {response.text}")
            return []

    except Exception as e:
        print(f"    ❌ Exception: {e}")
        return []

def process_moz_results(moz_results):
    """处理Moz API返回的结果"""
    processed_data = {}

    for result in moz_results:
        domain = result.get('root_domain')

        if domain:
            processed_data[domain] = {
                'domain_authority': result.get('domain_authority', 0),
                'page_authority': result.get('page_authority', 0),
                'spam_score': result.get('spam_score', 0),
                'root_domains_to_root_domain': result.get('root_domains_to_root_domain', 0),
                'external_pages_to_root_domain': result.get('external_pages_to_root_domain', 0),
                'pages_to_root_domain': result.get('pages_to_root_domain', 0),
                'top_backlinks': []
            }

    return processed_data

def enrich_domains_with_moz(domains_list, city_name, batch_size=10):
    """使用Moz API批量enrichment域名"""
    urls_to_process = []
    for domain in domains_list:
        if domain and domain.strip():
            url = f"https://{domain.strip()}/"
            urls_to_process.append(url)

    all_results = {}
    total_batches = (len(urls_to_process) + batch_size - 1) // batch_size

    for i in range(0, len(urls_to_process), batch_size):
        batch_urls = urls_to_process[i:i + batch_size]
        batch_num = (i // batch_size) + 1

        print(f"    📦 Batch {batch_num}/{total_batches}: {len(batch_urls)} URLs", end=" ")

        # 获取URL metrics
        moz_results = get_moz_url_metrics(batch_urls)

        if moz_results:
            processed_results = process_moz_results(moz_results)
            all_results.update(processed_results)
            print(f"✅ Got {len(processed_results)} domains")
        else:
            print("❌ Failed")

        # API限制延迟
        if batch_num < total_batches:
            time.sleep(2)

    return all_results

def save_progress(progress_data):
    """保存处理进度"""
    try:
        with open(PROGRESS_FILE, 'w') as f:
            json.dump(progress_data, f, indent=2)
    except Exception as e:
        print(f"⚠️ Failed to save progress: {e}")

def load_progress():
    """加载处理进度"""
    try:
        if os.path.exists(PROGRESS_FILE):
            with open(PROGRESS_FILE, 'r') as f:
                return json.load(f)
    except Exception as e:
        print(f"⚠️ Failed to load progress: {e}")

    return {
        "completed_files": [],
        "failed_files": [],
        "total_cost": 0,
        "total_domains": 0,
        "last_updated": None
    }

def process_single_file(city_name, file_type, progress_data):
    """处理单个文件并立即保存"""
    print(f"\n🏙️ Processing: {city_name} - {file_type.upper()}")
    print("=" * 70)

    # 检查是否已经处理过
    file_id = f"{city_name}_{file_type}"
    if file_id in progress_data["completed_files"]:
        print(f"✅ Already completed: {file_id}")
        return True

    # 构建文件路径
    if file_type == "top3":
        file_pattern = "*top_3*.csv"
    else:
        file_pattern = "*top_10*.csv"

    city_path = os.path.join(BASE_PATH, city_name)

    if not os.path.exists(city_path):
        print(f"❌ City directory not found: {city_path}")
        progress_data["failed_files"].append(f"{file_id} - Directory not found")
        return False

    matching_files = glob.glob(os.path.join(city_path, file_pattern))

    if not matching_files:
        print(f"❌ No {file_type} file found for {city_name}")
        progress_data["failed_files"].append(f"{file_id} - File not found")
        return False

    file_path = matching_files[0]
    print(f"📄 Found: {os.path.basename(file_path)}")

    try:
        # 读取数据
        df = pd.read_csv(file_path)
        print(f"📊 Loaded {len(df):,} rows")

        # 检查必要列
        required_columns = ["keyword", "city", "ranking", "link"]
        if not all(col in df.columns for col in required_columns):
            print(f"❌ Missing required columns")
            progress_data["failed_files"].append(f"{file_id} - Missing columns")
            return False

        # 提取域名
        df["domain"] = df["link"].apply(extract_domain)
        unique_domains = df["domain"].dropna().unique()

        print(f"🌐 Found {len(unique_domains)} unique domains")
        print(f"💰 Estimated cost: ${len(unique_domains) * 0.01:.2f}")

        # Moz enrichment
        print(f"📊 Starting Moz enrichment...")
        moz_results = enrich_domains_with_moz(unique_domains, city_name)

        if not moz_results:
            print(f"❌ No Moz results obtained")
            progress_data["failed_files"].append(f"{file_id} - No Moz data")
            return False

        # 应用结果到dataframe
        print(f"📋 Applying results to dataframe...")

        df["domain_authority"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("domain_authority", 0))
        df["page_authority"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("page_authority", 0))
        df["spam_score"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("spam_score", 0))
        df["backlinks_count"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("external_pages_to_root_domain", 0))
        df["referring_domains"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("root_domains_to_root_domain", 0))
        df["pages_to_domain"] = df["domain"].map(lambda d: moz_results.get(d, {}).get("pages_to_root_domain", 0))
        df["top_backlinks"] = df["domain"].map(lambda d: safe_join_backlinks(d, moz_results))
        df["trust_flow"] = None  # Moz不提供Trust Flow

        # 立即保存结果
        output_filename = f"{city_name}_{file_type}_moz_enriched.csv"
        output_path = os.path.join(OUTPUT_BASE_PATH, output_filename)
        df.to_csv(output_path, index=False)

        # 统计报告
        enriched_rows = (df["domain_authority"] > 0).sum()
        max_da = df["domain_authority"].max()
        avg_da = df[df["domain_authority"] > 0]["domain_authority"].mean() if enriched_rows > 0 else 0
        total_backlinks = df["backlinks_count"].sum()
        actual_cost = len(unique_domains) * 0.01

        print(f"\n📊 Results Summary:")
        print(f"💾 Saved: {output_filename}")
        print(f"📈 Enriched: {enriched_rows:,}/{len(df):,} rows")
        print(f"🏆 Max DA: {max_da}, Avg DA: {avg_da:.1f}")
        print(f"🔗 Total Backlinks: {total_backlinks:,}")
        print(f"💰 Cost: ${actual_cost:.2f}")

        # 更新进度
        progress_data["completed_files"].append(file_id)
        progress_data["total_cost"] += actual_cost
        progress_data["total_domains"] += len(unique_domains)
        progress_data["last_updated"] = datetime.now().isoformat()

        # 保存进度
        save_progress(progress_data)

        return True

    except Exception as e:
        print(f"❌ Error processing {city_name} {file_type}: {e}")
        progress_data["failed_files"].append(f"{file_id} - Processing error: {str(e)}")
        save_progress(progress_data)
        return False

def discover_all_cities():
    """发现所有城市"""
    print("🔍 Discovering all cities...")

    cities = []
    try:
        for item in os.listdir(BASE_PATH):
            item_path = os.path.join(BASE_PATH, item)
            if os.path.isdir(item_path) and not item.startswith('.'):
                cities.append(item)
    except Exception as e:
        print(f"❌ Error discovering cities: {e}")
        return []

    cities.sort()
    print(f"📁 Found {len(cities)} cities")
    return cities

def main():
    """主函数 - 处理所有城市"""
    print("🌟 ALL CITIES MOZ ENRICHMENT SYSTEM")
    print("=" * 100)
    print("🎯 Processing ALL cities TOP3 and TOP10 files")
    print("💾 Progressive saving - each file saved immediately")
    print("🔄 Resume capability - can restart from interruption")

    # 加载进度
    progress_data = load_progress()
    completed_count = len(progress_data["completed_files"])

    if completed_count > 0:
        print(f"\n📈 Resuming from previous session:")
        print(f"✅ Already completed: {completed_count} files")
        print(f"💰 Cost so far: ${progress_data['total_cost']:.2f}")
        print(f"🌐 Domains so far: {progress_data['total_domains']}")

    # 发现所有城市
    all_cities = discover_all_cities()
    if not all_cities:
        print("❌ No cities found!")
        return

    # 计算总工作量
    total_files = len(all_cities) * 2  # 每个城市2个文件(top3, top10)
    remaining_files = total_files - completed_count

    print(f"\n📊 Processing Overview:")
    print(f"🏙️ Total cities: {len(all_cities)}")
    print(f"📄 Total files: {total_files}")
    print(f"🔄 Remaining files: {remaining_files}")
    print(f"💰 Estimated remaining cost: ${remaining_files * 3:.2f} (avg $3/file)")
    print(f"⏱️ Estimated time: {remaining_files * 2:.0f} minutes (avg 2min/file)")

    # 开始处理
    print(f"\n🚀 Starting processing...")

    successful_files = []
    failed_files = []

    start_time = time.time()

    for i, city in enumerate(all_cities):
        print(f"\n🏙️ CITY {i+1}/{len(all_cities)}: {city}")
        print(f"📊 Progress: {((i)/len(all_cities)*100):.1f}%")

        # 处理TOP3
        success_top3 = process_single_file(city, "top3", progress_data)
        if success_top3:
            successful_files.append(f"{city}_top3")
        else:
            failed_files.append(f"{city}_top3")

        # 短暂延迟
        print("💤 Waiting 3 seconds...")
        time.sleep(3)

        # 处理TOP10
        success_top10 = process_single_file(city, "top10", progress_data)
        if success_top10:
            successful_files.append(f"{city}_top10")
        else:
            failed_files.append(f"{city}_top10")

        # 城市间延迟
        if i < len(all_cities) - 1:
            print("💤 Waiting 5 seconds before next city...")
            time.sleep(5)

        # 每10个城市显示进度
        if (i + 1) % 10 == 0:
            elapsed_time = time.time() - start_time
            avg_time_per_city = elapsed_time / (i + 1)
            remaining_cities = len(all_cities) - (i + 1)
            estimated_remaining = remaining_cities * avg_time_per_city

            print(f"\n📈 Progress Update:")
            print(f"✅ Completed cities: {i+1}/{len(all_cities)}")
            print(f"💰 Total cost so far: ${progress_data['total_cost']:.2f}")
            print(f"⏱️ Estimated time remaining: {estimated_remaining/60:.1f} minutes")

    # 最终报告
    total_completed = len(progress_data["completed_files"])
    total_failed = len(progress_data["failed_files"])

    print(f"\n🎉 ALL CITIES PROCESSING COMPLETE!")
    print("=" * 100)
    print(f"✅ Successfully processed: {total_completed} files")
    print(f"❌ Failed: {total_failed} files")
    print(f"💰 Total cost: ${progress_data['total_cost']:.2f}")
    print(f"🌐 Total domains: {progress_data['total_domains']:,}")
    print(f"📂 Results saved to: {OUTPUT_BASE_PATH}")

    # 显示失败的文件
    if progress_data["failed_files"]:
        print(f"\n❌ Failed files:")
        for failure in progress_data["failed_files"][-10:]:  # 显示最后10个失败
            print(f"  - {failure}")
        if len(progress_data["failed_files"]) > 10:
            print(f"  ... and {len(progress_data['failed_files']) - 10} more")

    print(f"\n✨ All enriched data ready for analysis!")
    print(f"🎯 {total_completed} CSV files with Domain Authority, Page Authority, and Backlinks data!")

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#     📦 Batch 61/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 62/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 63/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 64/105: 10 URLs ✅ Got 9 domains
#     📦 Batch 65/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 66/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 67/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 68/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 69/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 70/105: 10 URLs ✅ Got 9 domains
#     📦 Batch 71/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 72/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 73/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 74/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 75/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 76/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 77/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 78/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 79/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 80/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 81/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 82/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 83/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 84/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 85/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 86/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 87/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 88/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 89/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 90/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 91/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 92/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 93/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 94/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 95/105: 10 URLs ✅ Got 8 domains
#     📦 Batch 96/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 97/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 98/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 99/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 100/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 101/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 102/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 103/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 104/105: 10 URLs ✅ Got 10 domains
#     📦 Batch 105/105: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Columbia_top10_moz_enriched.csv
# 📈 Enriched: 4,616/4,862 rows
# 🏆 Max DA: 100, Avg DA: 32.5
# 🔗 Total Backlinks: 550,929,140,154
# 💰 Cost: $10.48
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 27/70: Columbus
# 📊 Progress: 37.1%
#
# 🏙️ Processing: Columbus - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,627 rows
# 🌐 Found 192 unique domains
# 💰 Estimated cost: $1.92
# 📊 Starting Moz enrichment...
#     📦 Batch 1/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/20: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Columbus_top3_moz_enriched.csv
# 📈 Enriched: 1,617/1,627 rows
# 🏆 Max DA: 94, Avg DA: 28.0
# 🔗 Total Backlinks: 28,207,558,607
# 💰 Cost: $1.92
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Columbus - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 6,035 rows
# 🌐 Found 482 unique domains
# 💰 Estimated cost: $4.82
# 📊 Starting Moz enrichment...
#     📦 Batch 1/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/49: 10 URLs ✅ Got 8 domains
#     📦 Batch 39/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/49: 10 URLs ✅ Got 9 domains
#     📦 Batch 46/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/49: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/49: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Columbus_top10_moz_enriched.csv
# 📈 Enriched: 5,992/6,035 rows
# 🏆 Max DA: 96, Avg DA: 28.7
# 🔗 Total Backlinks: 401,267,533,180
# 💰 Cost: $4.82
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 28/70: Coral Gables
# 📊 Progress: 38.6%
#
# 🏙️ Processing: Coral Gables - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,131 rows
# 🌐 Found 182 unique domains
# 💰 Estimated cost: $1.82
# 📊 Starting Moz enrichment...
#     📦 Batch 1/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/19: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/19: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Coral Gables_top3_moz_enriched.csv
# 📈 Enriched: 1,120/1,131 rows
# 🏆 Max DA: 92, Avg DA: 23.8
# 🔗 Total Backlinks: 199,474,003
# 💰 Cost: $1.82
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Coral Gables - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,854 rows
# 🌐 Found 442 unique domains
# 💰 Estimated cost: $4.42
# 📊 Starting Moz enrichment...
#     📦 Batch 1/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/45: 10 URLs ✅ Got 9 domains
#     📦 Batch 38/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/45: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/45: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Coral Gables_top10_moz_enriched.csv
# 📈 Enriched: 4,786/4,854 rows
# 🏆 Max DA: 99, Avg DA: 23.7
# 🔗 Total Backlinks: 57,911,605,004
# 💰 Cost: $4.42
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 29/70: Coral Springs
# 📊 Progress: 40.0%
#
# 🏙️ Processing: Coral Springs - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 929 rows
# 🌐 Found 125 unique domains
# 💰 Estimated cost: $1.25
# 📊 Starting Moz enrichment...
#     📦 Batch 1/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/13: 5 URLs ✅ Got 5 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Coral Springs_top3_moz_enriched.csv
# 📈 Enriched: 928/929 rows
# 🏆 Max DA: 71, Avg DA: 25.6
# 🔗 Total Backlinks: 41,854,500
# 💰 Cost: $1.25
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Coral Springs - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 3,557 rows
# 🌐 Found 359 unique domains
# 💰 Estimated cost: $3.59
# 📊 Starting Moz enrichment...
#     📦 Batch 1/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/36: 9 URLs ✅ Got 9 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Coral Springs_top10_moz_enriched.csv
# 📈 Enriched: 3,513/3,557 rows
# 🏆 Max DA: 99, Avg DA: 25.6
# 🔗 Total Backlinks: 93,059,280,673
# 💰 Cost: $3.59
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 30/70: Costa Mesa
# 📊 Progress: 41.4%
#
# 🏙️ Processing: Costa Mesa - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,119 rows
# 🌐 Found 179 unique domains
# 💰 Estimated cost: $1.79
# 📊 Starting Moz enrichment...
#     📦 Batch 1/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/18: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/18: 10 URLs ✅ Got 9 domains
#     📦 Batch 18/18: 9 URLs ✅ Got 9 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Costa Mesa_top3_moz_enriched.csv
# 📈 Enriched: 1,101/1,119 rows
# 🏆 Max DA: 92, Avg DA: 26.6
# 🔗 Total Backlinks: 9,574,160,083
# 💰 Cost: $1.79
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Costa Mesa - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,802 rows
# 🌐 Found 498 unique domains
# 💰 Estimated cost: $4.98
# 📊 Starting Moz enrichment...
#     📦 Batch 1/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/50: 10 URLs ✅ Got 9 domains
#     📦 Batch 33/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/50: 10 URLs ✅ Got 9 domains
#     📦 Batch 48/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/50: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Costa Mesa_top10_moz_enriched.csv
# 📈 Enriched: 4,702/4,802 rows
# 🏆 Max DA: 99, Avg DA: 28.1
# 🔗 Total Backlinks: 157,718,134,987
# 💰 Cost: $4.98
# 💤 Waiting 5 seconds before next city...
#
# 📈 Progress Update:
# ✅ Completed cities: 30/70
# 💰 Total cost so far: $192.75
# ⏱️ Estimated time remaining: 107.9 minutes
#
# 🏙️ CITY 31/70: Culver City
# 📊 Progress: 42.9%
#
# 🏙️ Processing: Culver City - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 874 rows
# 🌐 Found 156 unique domains
# 💰 Estimated cost: $1.56
# 📊 Starting Moz enrichment...
#     📦 Batch 1/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/16: 6 URLs ✅ Got 6 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Culver City_top3_moz_enriched.csv
# 📈 Enriched: 841/874 rows
# 🏆 Max DA: 97, Avg DA: 25.1
# 🔗 Total Backlinks: 11,906,114,589
# 💰 Cost: $1.56
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Culver City - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,143 rows
# 🌐 Found 425 unique domains
# 💰 Estimated cost: $4.25
# 📊 Starting Moz enrichment...
#     📦 Batch 1/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/43: 10 URLs ✅ Got 9 domains
#     📦 Batch 10/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/43: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/43: 5 URLs ✅ Got 5 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Culver City_top10_moz_enriched.csv
# 📈 Enriched: 3,939/4,143 rows
# 🏆 Max DA: 99, Avg DA: 27.0
# 🔗 Total Backlinks: 315,283,495,027
# 💰 Cost: $4.25
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 32/70: Dallas
# 📊 Progress: 44.3%
#
# 🏙️ Processing: Dallas - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,239 rows
# 🌐 Found 210 unique domains
# 💰 Estimated cost: $2.10
# 📊 Starting Moz enrichment...
#     📦 Batch 1/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/21: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/21: 10 URLs ✅ Got 10 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Dallas_top3_moz_enriched.csv
# 📈 Enriched: 1,140/1,239 rows
# 🏆 Max DA: 92, Avg DA: 29.1
# 🔗 Total Backlinks: 9,678,379,073
# 💰 Cost: $2.10
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Dallas - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,512 rows
# 🌐 Found 544 unique domains
# 💰 Estimated cost: $5.44
# 📊 Starting Moz enrichment...
#     📦 Batch 1/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 51/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 52/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 53/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 54/55: 10 URLs ✅ Got 10 domains
#     📦 Batch 55/55: 4 URLs ✅ Got 4 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Dallas_top10_moz_enriched.csv
# 📈 Enriched: 4,308/4,512 rows
# 🏆 Max DA: 99, Avg DA: 29.6
# 🔗 Total Backlinks: 245,564,575,708
# 💰 Cost: $5.44
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 33/70: Davie
# 📊 Progress: 45.7%
#
# 🏙️ Processing: Davie - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,074 rows
# 🌐 Found 226 unique domains
# 💰 Estimated cost: $2.26
# 📊 Starting Moz enrichment...
#     📦 Batch 1/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/23: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/23: 6 URLs ✅ Got 6 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Davie_top3_moz_enriched.csv
# 📈 Enriched: 1,055/1,074 rows
# 🏆 Max DA: 99, Avg DA: 27.6
# 🔗 Total Backlinks: 60,235,010,952
# 💰 Cost: $2.26
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Davie - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,408 rows
# 🌐 Found 588 unique domains
# 💰 Estimated cost: $5.88
# 📊 Starting Moz enrichment...
#     📦 Batch 1/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 51/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 52/59: 10 URLs ✅ Got 9 domains
#     📦 Batch 53/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 54/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 55/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 56/59: 10 URLs ✅ Got 9 domains
#     📦 Batch 57/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 58/59: 10 URLs ✅ Got 10 domains
#     📦 Batch 59/59: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Davie_top10_moz_enriched.csv
# 📈 Enriched: 4,309/4,408 rows
# 🏆 Max DA: 100, Avg DA: 27.5
# 🔗 Total Backlinks: 555,806,307,252
# 💰 Cost: $5.88
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 34/70: Denver
# 📊 Progress: 47.1%
#
# 🏙️ Processing: Denver - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,512 rows
# 🌐 Found 216 unique domains
# 💰 Estimated cost: $2.16
# 📊 Starting Moz enrichment...
#     📦 Batch 1/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/22: 10 URLs ✅ Got 9 domains
#     📦 Batch 15/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/22: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/22: 6 URLs ✅ Got 6 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Denver_top3_moz_enriched.csv
# 📈 Enriched: 1,501/1,512 rows
# 🏆 Max DA: 94, Avg DA: 30.5
# 🔗 Total Backlinks: 48,287,641,387
# 💰 Cost: $2.16
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Denver - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 5,372 rows
# 🌐 Found 522 unique domains
# 💰 Estimated cost: $5.22
# 📊 Starting Moz enrichment...
#     📦 Batch 1/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 51/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 52/53: 10 URLs ✅ Got 10 domains
#     📦 Batch 53/53: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Denver_top10_moz_enriched.csv
# 📈 Enriched: 5,345/5,372 rows
# 🏆 Max DA: 99, Avg DA: 30.5
# 🔗 Total Backlinks: 363,646,339,669
# 💰 Cost: $5.22
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 35/70: Des Moines
# 📊 Progress: 48.6%
#
# 🏙️ Processing: Des Moines - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,869 rows
# 🌐 Found 137 unique domains
# 💰 Estimated cost: $1.37
# 📊 Starting Moz enrichment...
#     📦 Batch 1/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/14: 10 URLs ✅ Got 9 domains
#     📦 Batch 12/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/14: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/14: 7 URLs ✅ Got 7 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Des Moines_top3_moz_enriched.csv
# 📈 Enriched: 1,861/1,869 rows
# 🏆 Max DA: 92, Avg DA: 28.5
# 🔗 Total Backlinks: 14,119,102,887
# 💰 Cost: $1.37
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Des Moines - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 6,263 rows
# 🌐 Found 330 unique domains
# 💰 Estimated cost: $3.30
# 📊 Starting Moz enrichment...
#     📦 Batch 1/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/33: 10 URLs ✅ Got 9 domains
#     📦 Batch 6/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/33: 10 URLs ✅ Got 9 domains
#     📦 Batch 15/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/33: 10 URLs ✅ Got 9 domains
#     📦 Batch 26/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/33: 10 URLs ✅ Got 10 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Des Moines_top10_moz_enriched.csv
# 📈 Enriched: 6,200/6,263 rows
# 🏆 Max DA: 99, Avg DA: 29.7
# 🔗 Total Backlinks: 385,781,715,943
# 💰 Cost: $3.30
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 36/70: Detroit
# 📊 Progress: 50.0%
#
# 🏙️ Processing: Detroit - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,268 rows
# 🌐 Found 158 unique domains
# 💰 Estimated cost: $1.58
# 📊 Starting Moz enrichment...
#     📦 Batch 1/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/16: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/16: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Detroit_top3_moz_enriched.csv
# 📈 Enriched: 1,244/1,268 rows
# 🏆 Max DA: 92, Avg DA: 30.7
# 🔗 Total Backlinks: 5,151,594,129
# 💰 Cost: $1.58
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Detroit - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,956 rows
# 🌐 Found 439 unique domains
# 💰 Estimated cost: $4.39
# 📊 Starting Moz enrichment...
#     📦 Batch 1/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/44: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/44: 9 URLs ✅ Got 9 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Detroit_top10_moz_enriched.csv
# 📈 Enriched: 4,833/4,956 rows
# 🏆 Max DA: 99, Avg DA: 30.9
# 🔗 Total Backlinks: 191,411,167,932
# 💰 Cost: $4.39
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 37/70: Durham
# 📊 Progress: 51.4%
#
# 🏙️ Processing: Durham - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,338 rows
# 🌐 Found 192 unique domains
# 💰 Estimated cost: $1.92
# 📊 Starting Moz enrichment...
#     📦 Batch 1/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/20: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/20: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Durham_top3_moz_enriched.csv
# 📈 Enriched: 1,333/1,338 rows
# 🏆 Max DA: 99, Avg DA: 28.1
# 🔗 Total Backlinks: 34,909,835,963
# 💰 Cost: $1.92
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Durham - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 5,138 rows
# 🌐 Found 500 unique domains
# 💰 Estimated cost: $5.00
# 📊 Starting Moz enrichment...
#     📦 Batch 1/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/50: 10 URLs ✅ Got 9 domains
#     📦 Batch 15/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/50: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/50: 10 URLs ✅ Got 10 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Durham_top10_moz_enriched.csv
# 📈 Enriched: 5,068/5,138 rows
# 🏆 Max DA: 100, Avg DA: 29.0
# 🔗 Total Backlinks: 620,744,516,950
# 💰 Cost: $5.00
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 38/70: El Segundo
# 📊 Progress: 52.9%
#
# 🏙️ Processing: El Segundo - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,152 rows
# 🌐 Found 141 unique domains
# 💰 Estimated cost: $1.41
# 📊 Starting Moz enrichment...
#     📦 Batch 1/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/15: 10 URLs ✅ Got 9 domains
#     📦 Batch 3/15: 10 URLs ✅ Got 8 domains
#     📦 Batch 4/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/15: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/15: 1 URLs ✅ Got 1 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: El Segundo_top3_moz_enriched.csv
# 📈 Enriched: 1,029/1,152 rows
# 🏆 Max DA: 96, Avg DA: 25.8
# 🔗 Total Backlinks: 7,544,596,730
# 💰 Cost: $1.41
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: El Segundo - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,317 rows
# 🌐 Found 399 unique domains
# 💰 Estimated cost: $3.99
# 📊 Starting Moz enrichment...
#     📦 Batch 1/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/40: 10 URLs ✅ Got 7 domains
#     📦 Batch 8/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/40: 10 URLs ✅ Got 9 domains
#     📦 Batch 39/40: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/40: 9 URLs ✅ Got 9 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: El Segundo_top10_moz_enriched.csv
# 📈 Enriched: 3,798/4,317 rows
# 🏆 Max DA: 99, Avg DA: 27.6
# ...
#     📦 Batch 29/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 51/68: 10 URLs ✅ Got 9 domains
#     📦 Batch 52/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 53/68: 10 URLs ✅ Got 8 domains
#     📦 Batch 54/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 55/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 56/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 57/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 58/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 59/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 60/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 61/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 62/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 63/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 64/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 65/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 66/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 67/68: 10 URLs ✅ Got 10 domains
#     📦 Batch 68/68: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Madison_top10_moz_enriched.csv
# 📈 Enriched: 5,465/5,596 rows
# 🏆 Max DA: 100, Avg DA: 31.7
# 🔗 Total Backlinks: 857,597,282,546
# 💰 Cost: $6.78
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 67/70: Maitland
# 📊 Progress: 94.3%
#
# 🏙️ Processing: Maitland - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,315 rows
# 🌐 Found 371 unique domains
# 💰 Estimated cost: $3.71
# 📊 Starting Moz enrichment...
#     📦 Batch 1/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/38: 10 URLs ✅ Got 9 domains
#     📦 Batch 23/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/38: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/38: 1 URLs ✅ Got 1 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Maitland_top3_moz_enriched.csv
# 📈 Enriched: 1,284/1,315 rows
# 🏆 Max DA: 99, Avg DA: 25.8
# 🔗 Total Backlinks: 170,191,335,490
# 💰 Cost: $3.71
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Maitland - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,723 rows
# 🌐 Found 907 unique domains
# 💰 Estimated cost: $9.07
# 📊 Starting Moz enrichment...
#     📦 Batch 1/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 35/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 37/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 38/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 39/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 40/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 41/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 42/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 43/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 44/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 45/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 46/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 47/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 48/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 49/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 50/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 51/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 52/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 53/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 54/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 55/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 56/91: 10 URLs ✅ Got 9 domains
#     📦 Batch 57/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 58/91: 10 URLs ✅ Got 9 domains
#     📦 Batch 59/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 60/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 61/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 62/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 63/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 64/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 65/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 66/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 67/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 68/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 69/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 70/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 71/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 72/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 73/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 74/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 75/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 76/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 77/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 78/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 79/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 80/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 81/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 82/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 83/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 84/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 85/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 86/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 87/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 88/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 89/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 90/91: 10 URLs ✅ Got 10 domains
#     📦 Batch 91/91: 7 URLs ✅ Got 7 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Maitland_top10_moz_enriched.csv
# 📈 Enriched: 4,484/4,723 rows
# 🏆 Max DA: 99, Avg DA: 27.6
# 🔗 Total Backlinks: 1,330,193,860,893
# 💰 Cost: $9.07
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 68/70: Manhattan Beach
# 📊 Progress: 95.7%
#
# 🏙️ Processing: Manhattan Beach - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,107 rows
# 🌐 Found 130 unique domains
# 💰 Estimated cost: $1.30
# 📊 Starting Moz enrichment...
#     📦 Batch 1/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/13: 10 URLs ✅ Got 9 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Manhattan Beach_top3_moz_enriched.csv
# 📈 Enriched: 1,027/1,107 rows
# 🏆 Max DA: 97, Avg DA: 23.5
# 🔗 Total Backlinks: 111,190,615,802
# 💰 Cost: $1.30
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Manhattan Beach - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 4,388 rows
# 🌐 Found 355 unique domains
# 💰 Estimated cost: $3.55
# 📊 Starting Moz enrichment...
#     📦 Batch 1/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/36: 10 URLs ✅ Got 9 domains
#     📦 Batch 12/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 34/36: 10 URLs ✅ Got 9 domains
#     📦 Batch 35/36: 10 URLs ✅ Got 10 domains
#     📦 Batch 36/36: 5 URLs ✅ Got 5 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: Manhattan Beach_top10_moz_enriched.csv
# 📈 Enriched: 4,088/4,388 rows
# 🏆 Max DA: 99, Avg DA: 25.8
# 🔗 Total Backlinks: 828,983,023,524
# 💰 Cost: $3.55
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 69/70: Moz_Enriched_Results
# 📊 Progress: 97.1%
#
# 🏙️ Processing: Moz_Enriched_Results - TOP3
# ======================================================================
# ❌ No top3 file found for Moz_Enriched_Results
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: Moz_Enriched_Results - TOP10
# ======================================================================
# ❌ No top10 file found for Moz_Enriched_Results
# 💤 Waiting 5 seconds before next city...
#
# 🏙️ CITY 70/70: little rock
# 📊 Progress: 98.6%
#
# 🏙️ Processing: little rock - TOP3
# ======================================================================
# 📄 Found: top_3_results_filtered.csv
# 📊 Loaded 1,406 rows
# 🌐 Found 128 unique domains
# 💰 Estimated cost: $1.28
# 📊 Starting Moz enrichment...
#     📦 Batch 1/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/13: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/13: 8 URLs ✅ Got 8 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: little rock_top3_moz_enriched.csv
# 📈 Enriched: 1,385/1,406 rows
# 🏆 Max DA: 92, Avg DA: 27.5
# 🔗 Total Backlinks: 33,055,768,342
# 💰 Cost: $1.28
# 💤 Waiting 3 seconds...
#
# 🏙️ Processing: little rock - TOP10
# ======================================================================
# 📄 Found: top_10_results_filtered.csv
# 📊 Loaded 5,454 rows
# 🌐 Found 322 unique domains
# 💰 Estimated cost: $3.22
# 📊 Starting Moz enrichment...
#     📦 Batch 1/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 2/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 3/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 4/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 5/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 6/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 7/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 8/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 9/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 10/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 11/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 12/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 13/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 14/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 15/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 16/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 17/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 18/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 19/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 20/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 21/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 22/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 23/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 24/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 25/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 26/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 27/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 28/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 29/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 30/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 31/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 32/33: 10 URLs ✅ Got 10 domains
#     📦 Batch 33/33: 2 URLs ✅ Got 2 domains
# 📋 Applying results to dataframe...
#
# 📊 Results Summary:
# 💾 Saved: little rock_top10_moz_enriched.csv
# 📈 Enriched: 5,344/5,454 rows
# 🏆 Max DA: 99, Avg DA: 27.1
# 🔗 Total Backlinks: 215,947,240,593
# 💰 Cost: $3.22
#
# 📈 Progress Update:
# ✅ Completed cities: 70/70
# 💰 Total cost so far: $494.37
# ⏱️ Estimated time remaining: 0.0 minutes
#
# 🎉 ALL CITIES PROCESSING COMPLETE!
# ====================================================================================================
# ✅ Successfully processed: 134 files
# ❌ Failed: 6 files
# 💰 Total cost: $494.37
# 🌐 Total domains: 49,437
# 📂 Results saved to: /content/drive/MyDrive/Part 1/Moz_Enriched_Results
#
# ❌ Failed files:
#   - Anchorage_top3 - File not found
#   - Anchorage_top10 - File not found
#   - Chattanooga_top3 - File not found
#   - Chattanooga_top10 - File not found
#   - Moz_Enriched_Results_top3 - File not found
#   - Moz_Enriched_Results_top10 - File not found
#
# ✨ All enriched data ready for analysis!
# 🎯 134 CSV files with Domain Authority, Page Authority, and Backlinks data!
